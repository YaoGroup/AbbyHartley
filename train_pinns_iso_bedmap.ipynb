# %% [markdown]
# # Isotropic viscosity inversion of ice shelves via PINNs

# %% [markdown]
# Fast running the code requires **GPU hardware** to accelerate.
#
# To choose GPU hardware, click the "Edit" in the toolbar above and select "Notebook settings".
#
# In the pop-up window, under the "Hardware accelerator", select "T4 GPU"

# %% [markdown]
# To ensure the code to run correctly in the colab, install the specific version of JAX below.
#
# (Note that only using the GPU version of JAX, combined with the selection of GPU hardware as mentioned above, can eventually accelerate the training.)

# %% [markdown]
# Copying required python functions from the [DIFFICE_jax](https://github.com/YaoGroup/DIFFICE_jax) GitHub repository

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# install the DIFFICE_jax
# !pip install DIFFICE_jax

# download the data from GitHub respository
# !wget https://github.com/YaoGroup/DIFFICE_jax/raw/main/examples/real_data/data_pinns_Amery.mat
# Out:
# Collecting DIFFICE_jax
#   Downloading diffice_jax-1.0.2-py3-none-any.whl.metadata (8.3 kB)
# Requirement already satisfied: jax>=0.4.20 in /usr/local/lib/python3.11/dist-packages (from DIFFICE_jax) (0.5.2)
# Requirement already satisfied: jaxlib>=0.4.20 in /usr/local/lib/python3.11/dist-packages (from DIFFICE_jax) (0.5.1)
# Requirement already satisfied: tensorflow-probability>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from DIFFICE_jax) (0.25.0)
# Requirement already satisfied: matplotlib>=3.8.0 in /usr/local/lib/python3.11/dist-packages (from DIFFICE_jax) (3.10.0)
# Requirement already satisfied: optax>=0.1.7 in /usr/local/lib/python3.11/dist-packages (from DIFFICE_jax) (0.2.5)
# Requirement already satisfied: ml_dtypes>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from jax>=0.4.20->DIFFICE_jax) (0.4.1)
# Requirement already satisfied: numpy>=1.25 in /usr/local/lib/python3.11/dist-packages (from jax>=0.4.20->DIFFICE_jax) (2.0.2)
# Requirement already satisfied: opt_einsum in /usr/local/lib/python3.11/dist-packages (from jax>=0.4.20->DIFFICE_jax) (3.4.0)
# Requirement already satisfied: scipy>=1.11.1 in /usr/local/lib/python3.11/dist-packages (from jax>=0.4.20->DIFFICE_jax) (1.15.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.8.0->DIFFICE_jax) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.8.0->DIFFICE_jax) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.8.0->DIFFICE_jax) (4.58.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.8.0->DIFFICE_jax) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.8.0->DIFFICE_jax) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.8.0->DIFFICE_jax) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.8.0->DIFFICE_jax) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.8.0->DIFFICE_jax) (2.9.0.post0)
# Requirement already satisfied: absl-py>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from optax>=0.1.7->DIFFICE_jax) (1.4.0)
# Requirement already satisfied: chex>=0.1.87 in /usr/local/lib/python3.11/dist-packages (from optax>=0.1.7->DIFFICE_jax) (0.1.89)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow-probability>=0.23.0->DIFFICE_jax) (1.17.0)
# Requirement already satisfied: decorator in /usr/local/lib/python3.11/dist-packages (from tensorflow-probability>=0.23.0->DIFFICE_jax) (4.4.2)
# Requirement already satisfied: cloudpickle>=1.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow-probability>=0.23.0->DIFFICE_jax) (3.1.1)
# Requirement already satisfied: gast>=0.3.2 in /usr/local/lib/python3.11/dist-packages (from tensorflow-probability>=0.23.0->DIFFICE_jax) (0.6.0)
# Requirement already satisfied: dm-tree in /usr/local/lib/python3.11/dist-packages (from tensorflow-probability>=0.23.0->DIFFICE_jax) (0.1.9)
# Requirement already satisfied: typing_extensions>=4.2.0 in /usr/local/lib/python3.11/dist-packages (from chex>=0.1.87->optax>=0.1.7->DIFFICE_jax) (4.14.0)
# Requirement already satisfied: toolz>=0.9.0 in /usr/local/lib/python3.11/dist-packages (from chex>=0.1.87->optax>=0.1.7->DIFFICE_jax) (0.12.1)
# Requirement already satisfied: attrs>=18.2.0 in /usr/local/lib/python3.11/dist-packages (from dm-tree->tensorflow-probability>=0.23.0->DIFFICE_jax) (25.3.0)
# Requirement already satisfied: wrapt>=1.11.2 in /usr/local/lib/python3.11/dist-packages (from dm-tree->tensorflow-probability>=0.23.0->DIFFICE_jax) (1.17.2)
# Downloading diffice_jax-1.0.2-py3-none-any.whl (29 kB)
# Installing collected packages: DIFFICE_jax
# Successfully installed DIFFICE_jax-1.0.2
# --2025-06-16 20:46:26--  https://github.com/YaoGroup/DIFFICE_jax/raw/main/examples/real_data/data_pinns_Amery.mat
# Resolving github.com (github.com)... 20.205.243.166
# Connecting to github.com (github.com)|20.205.243.166|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/YaoGroup/DIFFICE_jax/main/examples/real_data/data_pinns_Amery.mat [following]
# --2025-06-16 20:46:27--  https://raw.githubusercontent.com/YaoGroup/DIFFICE_jax/main/examples/real_data/data_pinns_Amery.mat
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2228601 (2.1M) [application/octet-stream]
# Saving to: ‘data_pinns_Amery.mat’
#
# data_pinns_Amery.ma 100%[===================>]   2.12M  --.-KB/s    in 0.01s
#
# 2025-06-16 20:46:27 (213 MB/s) - ‘data_pinns_Amery.mat’ saved [2228601/2228601]

# %% [markdown]
# Importing the required JAX library and function file from GitHub repository

# %%
import jax.numpy as jnp
import numpy as np
from jax import random
from jax.tree_util import tree_map
from scipy.io import loadmat
import time
import geopandas as gpd
import os
import pandas as pd
import h5py
import matplotlib.pyplot as plt
from scipy.ndimage import binary_erosion
from matplotlib.path import Path
from scipy.interpolate import griddata
from scipy.spatial import Delaunay
from mpl_toolkits.axes_grid1 import make_axes_locatable

from diffice_jax import normdata_pinn, dsample_pinn
from diffice_jax import vectgrad, ssa_iso, dbc_iso
from diffice_jax import init_pinn, solu_pinn
from diffice_jax import loss_iso_pinn
from diffice_jax import predict_pinn
from diffice_jax import adam_opt, lbfgs_opt

from matplotlib.colors import LogNorm
import imageio
import glob
import matplotlib.animation as animation
from matplotlib.image import imread

# %%
output_dir = '/content/drive/MyDrive/Colab Notebooks/amery/PINNplots_bedmap'
os.makedirs(output_dir, exist_ok=True)

# %% [markdown]
# # Setting hyperparameters
#
# hyper-parameters used for the training. Users are free to modify their value and check their influence on the training results

# %%
# select a random seed
seed = 2134
key = random.PRNGKey(seed)
np.random.seed(seed)

# create the subkeys
keys = random.split(key, 4)

# select the size of neural network
n_hl = 6
n_unit = 30
# set the weight for 1. equation loss and 2. boundary condition loss
lw = [0.05, 0.1]

# number of sampling points
n_smp = 5000    # for velocity data
nh_smp = 4500   # for thickness data
n_col = 5000    # for collocation points
n_cbd = 400     # for boundary condition (calving front)
# group all the number of points
n_pt = jnp.array([n_smp, nh_smp, n_col, n_cbd], dtype='int32')
# double the points for L-BFGS training
n_pt2 = n_pt * 2

# %% [markdown]
# # Data Loading
# load and normalize tne observed data before the PINN training

# %%
# load .mat data (from real data in diffice-jax)
rawdata = loadmat('data_pinns_Amery.mat')
xd = rawdata['xd']
yd = rawdata['yd']
hd_orig = rawdata['hd']  # original ice thickness, will replace with bedmap

# %%
# load bedmap data
folder = os.path.expanduser("/content/drive/MyDrive/Colab Notebooks/amery/bedmap_data")
gpq_files = [os.path.join(folder, f) for f in os.listdir(folder) if f.endswith('.gpq')]
bedmap_points = gpd.GeoDataFrame(pd.concat([gpd.read_parquet(f) for f in gpq_files], ignore_index=True))
bedmap_points = bedmap_points.dropna(subset=['Mean_thick'])

# %%
# extract coordinates and thickness
# ensure CRS is set
if bedmap_points.crs is None:
    bedmap_points.set_crs(epsg=4326, inplace=True)
# reproject to polar stereographic (to match DIFFICE grid)
bedmap_proj = bedmap_points.to_crs(epsg=3031)  # EPSG:3031 = Antarctic Polar Stereographic
x_bedmap = bedmap_proj.geometry.x.values
y_bedmap = bedmap_proj.geometry.y.values
thickness_bedmap = bedmap_proj['Mean_thick'].values

# %%
plt.figure(figsize=(8, 6))
plt.scatter(x_bedmap, y_bedmap, c='gray', s=0.5, label='Bedmap (projected)')
plt.scatter(xd.ravel(), yd.ravel(), c='red', s=0.5, label='DIFFICE grid')
plt.title("DIFFICE vs Bedmap Coordinates")
plt.axis('equal')
plt.legend()
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# Current DIFFICE (unshifted) bounds
x_min_dif, x_max_dif = np.nanmin(xd), np.nanmax(xd)
y_min_dif, y_max_dif = np.nanmin(yd), np.nanmax(yd)

# Bedmap bounds (already reprojected to EPSG:3031)
x_min_bed, x_max_bed = np.min(x_bedmap), np.max(x_bedmap)
y_min_bed, y_max_bed = np.min(y_bedmap), np.max(y_bedmap)

print("DIFFICE grid (xd, yd) range:")
print(f"  x: {x_min_dif:.1f} to {x_max_dif:.1f}")
print(f"  y: {y_min_dif:.1f} to {y_max_dif:.1f}")

print("Bedmap full range:")
print(f"  x: {x_min_bed:.1f} to {x_max_bed:.1f}")
print(f"  y: {y_min_bed:.1f} to {y_max_bed:.1f}")
# Out:
# DIFFICE grid (xd, yd) range:
#   x: 4378250.0 to 4782800.0
#   y: 2779200.0 to 2944350.0
# Bedmap full range:
#   x: -2644750.0 to 2677250.0
#   y: -2132750.0 to 2201750.0

# %%
# shift diffice grid to match bedmap data bounds properly
xd_shifted = xd - 2_560_000
yd_shifted = yd - 2_180_000

plt.figure(figsize=(8, 6))
plt.scatter(x_bedmap, y_bedmap, c='gray', s=0.5, label='Bedmap')
plt.scatter(xd_shifted.ravel(), yd_shifted.ravel(), c='red', s=0.5, label='Shifted DIFFICE')
plt.legend()
plt.axis('equal')
plt.title("Coordinate shift")
plt.show()

# %%
# Get valid bounding box of Amery grid
xd_shifted = xd - 2_560_000
yd_shifted = yd - 2_160_000

# Use the shifted bounding box to crop Bedmap points
margin = 10_000  # 10 km extra buffer
x_min = np.nanmin(xd_shifted) - margin
x_max = np.nanmax(xd_shifted) + margin
y_min = np.nanmin(yd_shifted) - margin
y_max = np.nanmax(yd_shifted) + margin

# Crop Bedmap points to that bounding box
in_bounds = ((x_bedmap >= x_min) & (x_bedmap <= x_max) &
    (y_bedmap >= y_min) & (y_bedmap <= y_max))

# Keep only valid thickness values within Amery bounds
valid_bedmap = (thickness_bedmap > 5) & in_bounds
x_bedmap_valid = x_bedmap[valid_bedmap]
y_bedmap_valid = y_bedmap[valid_bedmap]
thickness_valid = thickness_bedmap[valid_bedmap]
points_bedmap = np.column_stack((x_bedmap_valid, y_bedmap_valid))

# %%
from shapely.geometry import Polygon, Point
from skimage.measure import find_contours

# Step 1: Create a binary mask of the DIFFICE domain
# Assume some DIFFICE field (like mu, or u) exists with NaNs outside the domain
mask = np.isfinite(xd_shifted.reshape(xd.shape))  # or use e.g. mu or u if available

# Step 2: Use skimage to extract the boundary of the mask
contours = find_contours(mask.astype(float), level=0.5)

# Step 3: Use the longest contour (most complete boundary)
longest = max(contours, key=len)
i, j = longest[:, 0], longest[:, 1]  # row, col indices

# Step 4: Map array indices back to x/y coordinates
x_outline = xd_shifted.reshape(xd.shape)[i.astype(int), j.astype(int)]
y_outline = yd_shifted.reshape(yd.shape)[i.astype(int), j.astype(int)]

# Remove any NaNs
valid = np.isfinite(x_outline) & np.isfinite(y_outline)
x_outline = x_outline[valid]
y_outline = y_outline[valid]

# Step 5: Create polygon from outline
outline_coords = np.column_stack((x_outline, y_outline))
diffice_polygon = Polygon(outline_coords)

# Step 6: Convert Bedmap points to GeoDataFrame
bedmap_gdf = gpd.GeoDataFrame(
    {'thickness': thickness_bedmap},
    geometry=gpd.points_from_xy(x_bedmap, y_bedmap),
    crs="EPSG:3031"
)

# Step 7: Mask Bedmap points spatially
in_amery_mask = bedmap_gdf.within(diffice_polygon)
bedmap_amery = bedmap_gdf[in_amery_mask & (bedmap_gdf['thickness'] > 5)]

# Step 8: Plot
plt.figure(figsize=(8, 6))
plt.scatter(
    bedmap_amery.geometry.x, bedmap_amery.geometry.y,
    c=bedmap_amery['thickness'], s=0.5, vmin=0, vmax=1000, cmap='viridis'
)
plt.plot(x_outline, y_outline, color='red', linewidth=0.5, label='DIFFICE mask boundary')
plt.axis('equal')
plt.xlabel("x")
plt.ylabel("y")
plt.xlim(1.8e6, 2.25e6)
plt.ylim(550000, 850000)
plt.colorbar(label="Thickness (m)")
plt.legend()
plt.title("Bedmap Thickness")
#plt.savefig(f"{output_dir}/raw_bedmap_thickness_cropped.png")
plt.show()
# Out:
# WARNING:matplotlib.axes._base:Ignoring fixed y limits to fulfill fixed data aspect with adjustable data limits.

# %%
# Use raw ICESat-2 track points for thickness data
rawdata['hd'] = bedmap_amery['thickness'].values.reshape(-1, 1)
rawdata['xd_h'] = bedmap_amery.geometry.x.values.reshape(-1, 1)
rawdata['yd_h'] = bedmap_amery.geometry.y.values.reshape(-1, 1)

# %%
# normalize and prep for PINN training
data_all = normdata_pinn(rawdata)
scale = data_all[4][0:2]

# %%
# create functions to save plotted snapshots of inferred viscosity and residuals during each XX iteration of PINN training
# and to animate these into a video later

def save_training_snapshots(params, data_all, grid_shape, xd, yd, output_dir, iteration, method_name, scale):
    """Save training snapshots including viscosity and residual plots"""
    try:
        # Create the function group needed for predict_pinn (same as your working code)
        f_u = lambda x: pred_u(params, x)
        f_gu = lambda x: vectgrad(f_u, x)[0][:, 0:6]
        func_all = (f_u, f_gu, ssa_iso)

        # Get current predictions using predict_pinn (same as your working code)
        results = predict_pinn(func_all, data_all)

        # Save viscosity snapshot (using 'mu' key like in your working code)
        try:
            viscosity = results['mu']
            viscosity_reshaped = viscosity.reshape(grid_shape)

            # Handle NaN/Inf by computing color limits from finite values only
            finite_mask = np.isfinite(viscosity_reshaped)
            if finite_mask.any():
                vmin = np.min(viscosity_reshaped[finite_mask])
                vmax = np.max(viscosity_reshaped[finite_mask])
            else:
                print(f"Warning: All viscosity values are NaN/Inf at iteration {iteration}")
                vmin, vmax = 0, 1  # fallback values

            fig, ax = plt.subplots(figsize=(10, 5), dpi=70)
            h = ax.imshow(viscosity_reshaped, interpolation='nearest', cmap='rainbow',
                          extent=[0., 50000., 0,  80000.],
                          origin='lower', aspect='auto',
                          vmin=vmin, vmax=vmax)  # Use computed finite limits
            divider = make_axes_locatable(ax)
            cax = divider.append_axes("right", size="4%", pad=0.05)
            fig.colorbar(h, cax=cax)
            ax.set_xlabel('$x$', fontsize=15)
            ax.set_ylabel('$y\ $', fontsize=15, rotation=0)
            ax.set_title(f'Inferred viscosity $\mu(x,y)$ - {method_name} Iteration {iteration}', fontsize=15)
            fig.savefig(f"{output_dir}/mu_e1_e2_snaps/viscosity_{method_name}_iter_{iteration}.png", dpi=300, bbox_inches='tight')
            plt.close(fig)
            print(f"Saved viscosity at iteration {iteration}")
        except Exception as e:
            print(f"Failed to save viscosity at iteration {iteration}: {e}")

        # Save residual snapshots with FIXED COLOR LIMITS
        residual_keys = ['e1', 'e2']
        for key in residual_keys:
            if key in results:
                try:
                    residual = results[key]
                    reshaped = residual.reshape(grid_shape)

                    # Check if xd and yd have valid extents
                    if not (np.isfinite(xd.min()) and np.isfinite(xd.max()) and
                            np.isfinite(yd.min()) and np.isfinite(yd.max())):
                        print(f"Warning: xd/yd contains NaN/Inf at iteration {iteration}")
                        extent = [0, 1, 0, 1]  # fallback extent
                    else:
                        extent = [xd.min(), xd.max(), yd.min(), yd.max()]

                    fig, ax = plt.subplots(figsize=(10, 6), dpi=100)
                    # Use FIXED color limits to avoid NaN/Inf issues completely
                    h = ax.imshow(reshaped, interpolation='nearest', cmap='RdBu_r',
                                  extent=extent,
                                  origin='lower', aspect='auto',
                                  vmin=-1000, vmax=1000)  # FIXED LIMITS
                    divider = make_axes_locatable(ax)
                    cax = divider.append_axes("right", size="4%", pad=0.05)
                    fig.colorbar(h, cax=cax)
                    ax.set_title(f'{key} Residual - {method_name} Iteration {iteration}', fontsize=14)
                    ax.set_xlabel('x')
                    ax.set_ylabel('y')
                    fig.savefig(f"{output_dir}/mu_e1_e2_snaps/{key}_residual_{method_name}_iter_{iteration}.png", dpi=300, bbox_inches='tight')
                    plt.close(fig)
                    print(f"Saved {key} residual at iteration {iteration}")
                except Exception as e:
                    print(f"Failed to save {key} residual at iteration {iteration}: {e}")

        print(f"Saved snapshots for {method_name} iteration {iteration}")

    except Exception as e:
        print(f"Error saving snapshots at iteration {iteration}: {e}")
        import traceback
        traceback.print_exc()  # This will show exactly where the error occurs

def create_animation_gifs(output_dir):
    """
    Create GIF animations from saved frames
    """
    animation_dir = f"{output_dir}/animation_frames"

    # Create viscosity animation
    viscosity_files = sorted(glob.glob(f"{animation_dir}/viscosity_*.png"))
    if viscosity_files:
        images = []
        for filename in viscosity_files:
            images.append(imageio.imread(filename))
        imageio.mimsave(f"{output_dir}/viscosity_evolution.gif", images, duration=0.5)
        print(f"Created viscosity animation with {len(images)} frames")

    # Create residual animations
    for residual in ['e1', 'e2']:
        residual_files = sorted(glob.glob(f"{animation_dir}/{residual}_*.png"))
        if residual_files:
            images = []
            for filename in residual_files:
                images.append(imageio.imread(filename))
            imageio.mimsave(f"{output_dir}/{residual}_residual_evolution.gif", images, duration=0.5)
            print(f"Created {residual} residual animation with {len(images)} frames")

# Create directory for animation frames
os.makedirs(f"{output_dir}/animation_frames", exist_ok=True)

# %% [markdown]
# # Initialization
#
# initialize the neural network and loss function

# %%
# initialize the weights and biases of the network
trained_params = init_pinn(keys[0], n_hl, n_unit)

# create the solution function
pred_u = solu_pinn()

# create the data sampling function for Adam training
dataf = dsample_pinn(data_all, n_pt)
keys_adam = random.split(keys[1], 5)
# generate the data
data = dataf(keys_adam[0])

# create the data sampling function for L-BFGS training
dataf_l = dsample_pinn(data_all, n_pt2)
key_lbfgs = random.split(keys[2], 5)

# group the gov. eqn and bdry cond.
eqn_all = (ssa_iso, dbc_iso)
# create the loss function
NN_loss = loss_iso_pinn(pred_u, eqn_all, scale, lw)
# calculate the initial loss and set it as the reference value for loss
NN_loss.lref = NN_loss(trained_params, data)[0]

# %% [markdown]
# # Network training
#
# Since the real ice shelf data has more complicated profile than the synthetic data. 10000 iterations of Adam, followed by another 10000 iterations of L-BFGS can only infer a **very rough** profile of the ice viscosity.
#
# To train a high-accurate model, the number of iterations required for both Adam and L-BFGS optimization is more than 100k.

# %%
# modified adam training

# Define grid shape from your existing xd, yd arrays
grid_shape = xd.shape

# set the learning rate for Adam
lr = 1e-3
# set the training iteration
epoch1 = 10000
snapshot_interval = 100  # Save every 100 iterations

print("Starting Adam training with snapshots...")

# Initialize for Adam training

# Use existing adam_opt but with snapshot functionality
# --> modify the training to save snapshots during the existing adam_opt call

# Save initial snapshot
save_training_snapshots(trained_params, data_all, grid_shape, xd, yd, output_dir, 0, "Adam", scale)

# Create a custom callback version that saves snapshots
# Since adam_opt doesn't support callbacks, we'll use a wrapper approach
def adam_with_snapshots(key, loss_fn, init_params, data_fn, epochs, lr):
    # Use smaller chunks and save periodically
    chunk_size = snapshot_interval
    current_params = init_params
    all_losses = []

    total_iterations = 0

    for chunk_start in range(0, epochs, chunk_size):
        chunk_epochs = min(chunk_size, epochs - chunk_start)

        # Train for this chunk
        current_params, chunk_losses = adam_opt(key, loss_fn, current_params, data_fn, chunk_epochs, lr=lr)
        all_losses.extend(chunk_losses)

        total_iterations += chunk_epochs

        # Save snapshot after each chunk
        save_training_snapshots(current_params, data_all, grid_shape, xd, yd,
                              output_dir, total_iterations, "Adam", scale)

        print(f"Adam progress: {total_iterations}/{epochs} iterations completed")

        # Generate new key for next chunk
        key, _ = random.split(key)

    return current_params, all_losses

# Run Adam training with snapshots
trained_params, loss1 = adam_with_snapshots(keys_adam[1], NN_loss, trained_params, dataf, epoch1, lr)
# Out:
# Step: 100 | Loss: 1.3130e-01 | Loss_d: 1.5282e-01 | Loss_e: 4.2041e-02 | Loss_b: 2.1018e-03
# Step: 200 | Loss: 7.3740e-02 | Loss_d: 7.7128e-02 | Loss_e: 1.8367e-01 | Loss_b: 8.1467e-03
# Step: 300 | Loss: 4.6223e-02 | Loss_d: 4.7686e-02 | Loss_e: 1.1539e-01 | Loss_b: 1.1584e-02
# Step: 400 | Loss: 3.3964e-02 | Loss_d: 3.5391e-02 | Loss_e: 7.3716e-02 | Loss_b: 1.0527e-02
# Step: 500 | Loss: 3.0425e-02 | Loss_d: 3.2605e-02 | Loss_e: 4.6521e-02 | Loss_b: 1.0173e-02
# Step: 600 | Loss: 2.7900e-02 | Loss_d: 3.0312e-02 | Loss_e: 3.1660e-02 | Loss_b: 1.0705e-02
# Step: 700 | Loss: 2.7138e-02 | Loss_d: 2.9357e-02 | Loss_e: 3.4140e-02 | Loss_b: 1.0001e-02
# Step: 800 | Loss: 2.5832e-02 | Loss_d: 2.7691e-02 | Loss_e: 3.8291e-02 | Loss_b: 9.1601e-03
# Step: 900 | Loss: 2.6156e-02 | Loss_d: 2.7819e-02 | Loss_e: 4.2906e-02 | Loss_b: 9.4010e-03
# Step: 1000 | Loss: 2.3340e-02 | Loss_d: 2.4340e-02 | Loss_e: 4.7056e-02 | Loss_b: 8.8432e-03
# Step: 1100 | Loss: 2.4043e-02 | Loss_d: 2.5240e-02 | Loss_e: 4.9582e-02 | Loss_b: 6.8890e-03
# Step: 1200 | Loss: 2.2873e-02 | Loss_d: 2.4069e-02 | Loss_e: 4.5090e-02 | Loss_b: 7.0138e-03
# Step: 1300 | Loss: 2.1933e-02 | Loss_d: 2.3057e-02 | Loss_e: 4.4275e-02 | Loss_b: 6.4331e-03
# Step: 1400 | Loss: 2.1142e-02 | Loss_d: 2.2245e-02 | Loss_e: 4.2043e-02 | Loss_b: 6.3304e-03
# Step: 1500 | Loss: 2.1363e-02 | Loss_d: 2.2606e-02 | Loss_e: 3.8386e-02 | Loss_b: 7.1562e-03
# Step: 1600 | Loss: 1.9317e-02 | Loss_d: 2.0575e-02 | Loss_e: 3.3407e-02 | Loss_b: 5.7943e-03
# Step: 1700 | Loss: 1.9814e-02 | Loss_d: 2.1167e-02 | Loss_e: 3.4145e-02 | Loss_b: 5.3653e-03
# Step: 1800 | Loss: 1.8703e-02 | Loss_d: 2.0280e-02 | Loss_e: 2.8400e-02 | Loss_b: 3.9815e-03
# Step: 1900 | Loss: 1.8286e-02 | Loss_d: 1.9824e-02 | Loss_e: 2.8347e-02 | Loss_b: 3.6456e-03
# Step: 2000 | Loss: 1.8039e-02 | Loss_d: 1.9485e-02 | Loss_e: 2.6461e-02 | Loss_b: 5.0653e-03
# Step: 2100 | Loss: 1.8254e-02 | Loss_d: 1.9856e-02 | Loss_e: 2.6601e-02 | Loss_b: 3.8099e-03
# Step: 2200 | Loss: 1.7629e-02 | Loss_d: 1.9232e-02 | Loss_e: 2.4556e-02 | Loss_b: 3.6903e-03
# Step: 2300 | Loss: 1.7741e-02 | Loss_d: 1.9406e-02 | Loss_e: 2.4029e-02 | Loss_b: 3.5316e-03
# Step: 2400 | Loss: 1.7194e-02 | Loss_d: 1.8846e-02 | Loss_e: 2.2936e-02 | Loss_b: 3.2273e-03
# Step: 2500 | Loss: 1.7987e-02 | Loss_d: 1.9820e-02 | Loss_e: 2.0802e-02 | Loss_b: 3.9222e-03
# Step: 2600 | Loss: 1.7572e-02 | Loss_d: 1.9135e-02 | Loss_e: 2.5334e-02 | Loss_b: 3.6042e-03
# Step: 2700 | Loss: 1.5970e-02 | Loss_d: 1.7468e-02 | Loss_e: 2.0399e-02 | Loss_b: 3.8173e-03
# Step: 2800 | Loss: 1.6124e-02 | Loss_d: 1.7711e-02 | Loss_e: 1.9602e-02 | Loss_b: 3.6002e-03
# Step: 2900 | Loss: 1.6495e-02 | Loss_d: 1.8322e-02 | Loss_e: 1.8179e-02 | Loss_b: 2.5887e-03
# Step: 3000 | Loss: 1.6586e-02 | Loss_d: 1.8372e-02 | Loss_e: 1.8410e-02 | Loss_b: 3.0399e-03
# Step: 3100 | Loss: 1.6672e-02 | Loss_d: 1.8366e-02 | Loss_e: 1.9614e-02 | Loss_b: 3.5164e-03
# Step: 3200 | Loss: 1.5009e-02 | Loss_d: 1.6609e-02 | Loss_e: 1.6642e-02 | Loss_b: 2.9156e-03
# Step: 3300 | Loss: 1.5271e-02 | Loss_d: 1.6896e-02 | Loss_e: 1.7538e-02 | Loss_b: 2.7062e-03
# Step: 3400 | Loss: 1.6088e-02 | Loss_d: 1.7792e-02 | Loss_e: 1.7433e-02 | Loss_b: 3.4467e-03
# Step: 3500 | Loss: 1.5756e-02 | Loss_d: 1.7401e-02 | Loss_e: 1.6646e-02 | Loss_b: 3.8326e-03
# Step: 3600 | Loss: 1.5444e-02 | Loss_d: 1.7077e-02 | Loss_e: 1.7160e-02 | Loss_b: 3.1283e-03
# Step: 3700 | Loss: 1.5674e-02 | Loss_d: 1.7440e-02 | Loss_e: 1.5576e-02 | Loss_b: 3.0003e-03
# Step: 3800 | Loss: 1.6024e-02 | Loss_d: 1.7808e-02 | Loss_e: 1.5922e-02 | Loss_b: 3.2905e-03
# Step: 3900 | Loss: 1.4924e-02 | Loss_d: 1.6482e-02 | Loss_e: 1.6334e-02 | Loss_b: 3.3419e-03
# Step: 4000 | Loss: 1.6051e-02 | Loss_d: 1.7800e-02 | Loss_e: 1.7051e-02 | Loss_b: 3.1260e-03
# Step: 4100 | Loss: 1.4441e-02 | Loss_d: 1.5908e-02 | Loss_e: 1.6964e-02 | Loss_b: 3.0672e-03
# Step: 4200 | Loss: 1.4251e-02 | Loss_d: 1.5620e-02 | Loss_e: 1.7334e-02 | Loss_b: 3.5084e-03
# Step: 4300 | Loss: 1.4640e-02 | Loss_d: 1.6213e-02 | Loss_e: 1.5947e-02 | Loss_b: 2.8730e-03
# Step: 4400 | Loss: 1.4294e-02 | Loss_d: 1.5789e-02 | Loss_e: 1.6110e-02 | Loss_b: 2.9499e-03
# Step: 4500 | Loss: 1.5687e-02 | Loss_d: 1.7542e-02 | Loss_e: 1.5375e-02 | Loss_b: 2.2437e-03
# Step: 4600 | Loss: 1.4507e-02 | Loss_d: 1.5977e-02 | Loss_e: 1.6678e-02 | Loss_b: 3.2916e-03
# Step: 4700 | Loss: 1.3127e-02 | Loss_d: 1.4404e-02 | Loss_e: 1.6618e-02 | Loss_b: 2.7535e-03
# Step: 4800 | Loss: 1.4379e-02 | Loss_d: 1.6019e-02 | Loss_e: 1.5138e-02 | Loss_b: 2.1324e-03
# Step: 4900 | Loss: 1.3105e-02 | Loss_d: 1.4421e-02 | Loss_e: 1.4903e-02 | Loss_b: 3.1841e-03
# Step: 5000 | Loss: 1.4650e-02 | Loss_d: 1.6278e-02 | Loss_e: 1.5941e-02 | Loss_b: 2.3545e-03
# Step: 5100 | Loss: 1.3630e-02 | Loss_d: 1.5027e-02 | Loss_e: 1.6050e-02 | Loss_b: 2.7486e-03
# Step: 5200 | Loss: 1.4750e-02 | Loss_d: 1.6266e-02 | Loss_e: 1.7165e-02 | Loss_b: 3.0321e-03
# Step: 5300 | Loss: 1.4542e-02 | Loss_d: 1.6114e-02 | Loss_e: 1.5956e-02 | Loss_b: 2.6978e-03
# Step: 5400 | Loss: 1.4144e-02 | Loss_d: 1.5552e-02 | Loss_e: 1.6336e-02 | Loss_b: 3.4325e-03
# Step: 5500 | Loss: 1.2766e-02 | Loss_d: 1.4095e-02 | Loss_e: 1.4788e-02 | Loss_b: 2.4820e-03
# Step: 5600 | Loss: 1.4373e-02 | Loss_d: 1.5963e-02 | Loss_e: 1.5661e-02 | Loss_b: 2.3565e-03
# Step: 5700 | Loss: 1.5463e-02 | Loss_d: 1.7291e-02 | Loss_e: 1.3776e-02 | Loss_b: 2.9041e-03
# Step: 5800 | Loss: 1.3901e-02 | Loss_d: 1.5420e-02 | Loss_e: 1.4019e-02 | Loss_b: 3.0387e-03
# Step: 5900 | Loss: 1.2728e-02 | Loss_d: 1.4087e-02 | Loss_e: 1.3961e-02 | Loss_b: 2.5429e-03
# Step: 6000 | Loss: 1.3951e-02 | Loss_d: 1.5421e-02 | Loss_e: 1.6122e-02 | Loss_b: 2.5704e-03
# Step: 6100 | Loss: 1.3561e-02 | Loss_d: 1.4913e-02 | Loss_e: 1.7840e-02 | Loss_b: 2.1780e-03
# Step: 6200 | Loss: 1.1735e-02 | Loss_d: 1.2856e-02 | Loss_e: 1.4949e-02 | Loss_b: 2.6239e-03
# Step: 6300 | Loss: 1.4040e-02 | Loss_d: 1.5572e-02 | Loss_e: 1.4495e-02 | Loss_b: 2.9277e-03
# Step: 6400 | Loss: 1.3210e-02 | Loss_d: 1.4645e-02 | Loss_e: 1.4730e-02 | Loss_b: 2.2620e-03
# Step: 6500 | Loss: 1.2965e-02 | Loss_d: 1.4362e-02 | Loss_e: 1.4128e-02 | Loss_b: 2.5049e-03
# Step: 6600 | Loss: 1.3153e-02 | Loss_d: 1.4588e-02 | Loss_e: 1.4969e-02 | Loss_b: 2.0429e-03
# Step: 6700 | Loss: 1.2584e-02 | Loss_d: 1.3933e-02 | Loss_e: 1.3540e-02 | Loss_b: 2.5748e-03
# Step: 6800 | Loss: 1.2675e-02 | Loss_d: 1.4068e-02 | Loss_e: 1.3687e-02 | Loss_b: 2.2349e-03
# Step: 6900 | Loss: 1.3654e-02 | Loss_d: 1.4990e-02 | Loss_e: 1.7173e-02 | Loss_b: 2.8405e-03
# Step: 7000 | Loss: 1.2334e-02 | Loss_d: 1.3535e-02 | Loss_e: 1.5879e-02 | Loss_b: 2.4467e-03
# Step: 7100 | Loss: 1.3141e-02 | Loss_d: 1.4350e-02 | Loss_e: 1.6599e-02 | Loss_b: 3.4681e-03
# Step: 7200 | Loss: 1.3328e-02 | Loss_d: 1.4815e-02 | Loss_e: 1.3970e-02 | Loss_b: 2.3453e-03
# Step: 7300 | Loss: 1.2546e-02 | Loss_d: 1.3750e-02 | Loss_e: 1.6094e-02 | Loss_b: 2.6914e-03
# Step: 7400 | Loss: 1.2247e-02 | Loss_d: 1.3402e-02 | Loss_e: 1.6697e-02 | Loss_b: 2.3348e-03
# Step: 7500 | Loss: 1.3136e-02 | Loss_d: 1.4327e-02 | Loss_e: 1.9340e-02 | Loss_b: 2.2715e-03
# Step: 7600 | Loss: 1.2392e-02 | Loss_d: 1.3616e-02 | Loss_e: 1.5358e-02 | Loss_b: 2.5772e-03
# Step: 7700 | Loss: 1.2866e-02 | Loss_d: 1.4172e-02 | Loss_e: 1.4199e-02 | Loss_b: 3.1966e-03
# Step: 7800 | Loss: 1.1714e-02 | Loss_d: 1.2871e-02 | Loss_e: 1.4986e-02 | Loss_b: 2.2065e-03
# Step: 7900 | Loss: 1.2297e-02 | Loss_d: 1.3553e-02 | Loss_e: 1.4230e-02 | Loss_b: 2.6517e-03
# Step: 8000 | Loss: 1.2685e-02 | Loss_d: 1.4002e-02 | Loss_e: 1.4890e-02 | Loss_b: 2.4132e-03
# Step: 8100 | Loss: 1.2321e-02 | Loss_d: 1.3522e-02 | Loss_e: 1.6019e-02 | Loss_b: 2.3457e-03
# Step: 8200 | Loss: 1.2164e-02 | Loss_d: 1.3396e-02 | Loss_e: 1.4898e-02 | Loss_b: 2.3177e-03
# Step: 8300 | Loss: 1.2310e-02 | Loss_d: 1.3463e-02 | Loss_e: 1.5302e-02 | Loss_b: 3.1682e-03
# Step: 8400 | Loss: 1.2851e-02 | Loss_d: 1.4187e-02 | Loss_e: 1.5119e-02 | Loss_b: 2.4176e-03
# Step: 8500 | Loss: 1.2312e-02 | Loss_d: 1.3686e-02 | Loss_e: 1.2878e-02 | Loss_b: 2.1776e-03
# Step: 8600 | Loss: 1.2158e-02 | Loss_d: 1.3121e-02 | Loss_e: 1.9261e-02 | Loss_b: 2.8043e-03
# Step: 8700 | Loss: 1.3134e-02 | Loss_d: 1.4401e-02 | Loss_e: 1.8681e-02 | Loss_b: 1.8335e-03
# Step: 8800 | Loss: 1.2938e-02 | Loss_d: 1.4355e-02 | Loss_e: 1.3310e-02 | Loss_b: 2.6682e-03
# Step: 8900 | Loss: 1.3114e-02 | Loss_d: 1.4537e-02 | Loss_e: 1.4745e-02 | Loss_b: 2.1980e-03
# Step: 9000 | Loss: 1.1872e-02 | Loss_d: 1.3074e-02 | Loss_e: 1.4198e-02 | Loss_b: 2.4346e-03
# Step: 9100 | Loss: 1.1042e-02 | Loss_d: 1.2161e-02 | Loss_e: 1.3761e-02 | Loss_b: 1.9799e-03
# Step: 9200 | Loss: 1.2094e-02 | Loss_d: 1.3416e-02 | Loss_e: 1.3246e-02 | Loss_b: 2.1113e-03
# Step: 9300 | Loss: 1.2460e-02 | Loss_d: 1.3825e-02 | Loss_e: 1.2609e-02 | Loss_b: 2.6585e-03
# Step: 9400 | Loss: 1.2028e-02 | Loss_d: 1.3151e-02 | Loss_e: 1.6704e-02 | Loss_b: 2.2589e-03
# Step: 9500 | Loss: 1.1170e-02 | Loss_d: 1.2188e-02 | Loss_e: 1.5059e-02 | Loss_b: 2.5741e-03
# Step: 9600 | Loss: 1.2432e-02 | Loss_d: 1.3786e-02 | Loss_e: 1.4459e-02 | Loss_b: 1.7979e-03
# Step: 9700 | Loss: 1.1205e-02 | Loss_d: 1.2280e-02 | Loss_e: 1.5276e-02 | Loss_b: 1.9498e-03
# Step: 9800 | Loss: 1.1674e-02 | Loss_d: 1.2947e-02 | Loss_e: 1.2396e-02 | Loss_b: 2.2673e-03
# Step: 9900 | Loss: 1.2255e-02 | Loss_d: 1.3758e-02 | Loss_e: 1.1226e-02 | Loss_b: 1.6098e-03
# Step: 10000 | Loss: 1.1517e-02 | Loss_d: 1.2699e-02 | Loss_e: 1.4198e-02 | Loss_b: 1.9885e-03

# %%
# Modified L-BFGS training

# set the training iteration
epoch2 = 10000

print("Starting L-BFGS training with snapshots...")

# Save initial L-BFGS snapshot
save_training_snapshots(trained_params, data_all, grid_shape, xd, yd, output_dir, 0, "LBFGS", scale)

# Use chunked approach for L-BFGS as well
def lbfgs_with_snapshots(loss_fn, init_params, data, epochs):
    chunk_size = snapshot_interval
    current_params = init_params
    all_losses = []

    total_iterations = 0

    for chunk_start in range(0, epochs, chunk_size):
        chunk_epochs = min(chunk_size, epochs - chunk_start)

        # Train for this chunk
        current_params, chunk_losses = lbfgs_opt(loss_fn, current_params, data, chunk_epochs)
        all_losses.extend(chunk_losses)

        total_iterations += chunk_epochs

        # Save snapshot after each chunk
        save_training_snapshots(current_params, data_all, grid_shape, xd, yd,
                              output_dir, total_iterations, "LBFGS", scale)

        print(f"L-BFGS progress: {total_iterations}/{epochs} iterations completed")

    return current_params, all_losses

# Run L-BFGS training with snapshots
trained_params2, loss2 = lbfgs_with_snapshots(NN_loss, trained_params, data_l, epoch2)

# %%
# Create animations after training is complete
print("Creating animation GIFs...")
create_animation_gifs(output_dir/mu_e1_e2_snaps)

print("Training complete! Check the output directory for:")
print(f"- Individual frames in: {output_dir}/animation_frames/")
print(f"- Viscosity evolution GIF: {output_dir}/viscosity_evolution.gif")
print(f"- Residual evolution GIFs: {output_dir}/e1_residual_evolution.gif and {output_dir}/e2_residual_evolution.gif")

# %%
# # set the learning rate for Adam
# lr = 1e-3
# # set the training iteration
# epoch1 = 10000

# # training with Adam
# trained_params, loss1 = adam_opt(keys_adam[1], NN_loss, trained_params, dataf, epoch1, lr=lr)
# Out:
# Step: 100 | Loss: 1.3130e-01 | Loss_d: 1.5282e-01 | Loss_e: 4.2041e-02 | Loss_b: 2.1018e-03
# Step: 200 | Loss: 7.3740e-02 | Loss_d: 7.7128e-02 | Loss_e: 1.8367e-01 | Loss_b: 8.1467e-03
# Step: 300 | Loss: 4.6223e-02 | Loss_d: 4.7686e-02 | Loss_e: 1.1539e-01 | Loss_b: 1.1584e-02
# Step: 400 | Loss: 3.3964e-02 | Loss_d: 3.5391e-02 | Loss_e: 7.3716e-02 | Loss_b: 1.0527e-02
# Step: 500 | Loss: 3.0425e-02 | Loss_d: 3.2605e-02 | Loss_e: 4.6521e-02 | Loss_b: 1.0173e-02
# Step: 600 | Loss: 2.7900e-02 | Loss_d: 3.0312e-02 | Loss_e: 3.1660e-02 | Loss_b: 1.0705e-02
# Step: 700 | Loss: 2.7138e-02 | Loss_d: 2.9357e-02 | Loss_e: 3.4140e-02 | Loss_b: 1.0001e-02
# Step: 800 | Loss: 2.5832e-02 | Loss_d: 2.7691e-02 | Loss_e: 3.8291e-02 | Loss_b: 9.1601e-03
# Step: 900 | Loss: 2.6156e-02 | Loss_d: 2.7819e-02 | Loss_e: 4.2905e-02 | Loss_b: 9.4010e-03
# Step: 1000 | Loss: 2.3340e-02 | Loss_d: 2.4340e-02 | Loss_e: 4.7056e-02 | Loss_b: 8.8432e-03
# Step: 1100 | Loss: 2.4043e-02 | Loss_d: 2.5240e-02 | Loss_e: 4.9582e-02 | Loss_b: 6.8890e-03
# Step: 1200 | Loss: 2.2873e-02 | Loss_d: 2.4069e-02 | Loss_e: 4.5090e-02 | Loss_b: 7.0138e-03
# Step: 1300 | Loss: 2.1933e-02 | Loss_d: 2.3057e-02 | Loss_e: 4.4275e-02 | Loss_b: 6.4331e-03
# Step: 1400 | Loss: 2.1142e-02 | Loss_d: 2.2245e-02 | Loss_e: 4.2043e-02 | Loss_b: 6.3305e-03
# Step: 1500 | Loss: 2.1363e-02 | Loss_d: 2.2606e-02 | Loss_e: 3.8386e-02 | Loss_b: 7.1562e-03
# Step: 1600 | Loss: 1.9317e-02 | Loss_d: 2.0575e-02 | Loss_e: 3.3407e-02 | Loss_b: 5.7943e-03
# Step: 1700 | Loss: 1.9814e-02 | Loss_d: 2.1167e-02 | Loss_e: 3.4145e-02 | Loss_b: 5.3653e-03
# Step: 1800 | Loss: 1.8703e-02 | Loss_d: 2.0280e-02 | Loss_e: 2.8400e-02 | Loss_b: 3.9815e-03
# Step: 1900 | Loss: 1.8286e-02 | Loss_d: 1.9824e-02 | Loss_e: 2.8347e-02 | Loss_b: 3.6456e-03
# Step: 2000 | Loss: 1.8039e-02 | Loss_d: 1.9485e-02 | Loss_e: 2.6461e-02 | Loss_b: 5.0653e-03
# Step: 2100 | Loss: 1.8254e-02 | Loss_d: 1.9856e-02 | Loss_e: 2.6601e-02 | Loss_b: 3.8099e-03
# Step: 2200 | Loss: 1.7629e-02 | Loss_d: 1.9232e-02 | Loss_e: 2.4556e-02 | Loss_b: 3.6903e-03
# Step: 2300 | Loss: 1.7741e-02 | Loss_d: 1.9406e-02 | Loss_e: 2.4029e-02 | Loss_b: 3.5316e-03
# Step: 2400 | Loss: 1.7194e-02 | Loss_d: 1.8846e-02 | Loss_e: 2.2936e-02 | Loss_b: 3.2273e-03
# Step: 2500 | Loss: 1.7987e-02 | Loss_d: 1.9820e-02 | Loss_e: 2.0802e-02 | Loss_b: 3.9222e-03
# Step: 2600 | Loss: 1.7572e-02 | Loss_d: 1.9135e-02 | Loss_e: 2.5334e-02 | Loss_b: 3.6042e-03
# Step: 2700 | Loss: 1.5970e-02 | Loss_d: 1.7468e-02 | Loss_e: 2.0399e-02 | Loss_b: 3.8173e-03
# Step: 2800 | Loss: 1.6124e-02 | Loss_d: 1.7711e-02 | Loss_e: 1.9602e-02 | Loss_b: 3.6002e-03
# Step: 2900 | Loss: 1.6495e-02 | Loss_d: 1.8322e-02 | Loss_e: 1.8179e-02 | Loss_b: 2.5887e-03
# Step: 3000 | Loss: 1.6586e-02 | Loss_d: 1.8372e-02 | Loss_e: 1.8410e-02 | Loss_b: 3.0399e-03
# Step: 3100 | Loss: 1.6672e-02 | Loss_d: 1.8366e-02 | Loss_e: 1.9613e-02 | Loss_b: 3.5163e-03
# Step: 3200 | Loss: 1.5009e-02 | Loss_d: 1.6609e-02 | Loss_e: 1.6644e-02 | Loss_b: 2.9156e-03
# Step: 3300 | Loss: 1.5271e-02 | Loss_d: 1.6896e-02 | Loss_e: 1.7538e-02 | Loss_b: 2.7062e-03
# Step: 3400 | Loss: 1.6088e-02 | Loss_d: 1.7792e-02 | Loss_e: 1.7432e-02 | Loss_b: 3.4466e-03
# Step: 3500 | Loss: 1.5756e-02 | Loss_d: 1.7401e-02 | Loss_e: 1.6647e-02 | Loss_b: 3.8327e-03
# Step: 3600 | Loss: 1.5444e-02 | Loss_d: 1.7077e-02 | Loss_e: 1.7160e-02 | Loss_b: 3.1283e-03
# Step: 3700 | Loss: 1.5674e-02 | Loss_d: 1.7440e-02 | Loss_e: 1.5576e-02 | Loss_b: 3.0003e-03
# Step: 3800 | Loss: 1.6024e-02 | Loss_d: 1.7808e-02 | Loss_e: 1.5922e-02 | Loss_b: 3.2905e-03
# Step: 3900 | Loss: 1.4924e-02 | Loss_d: 1.6482e-02 | Loss_e: 1.6334e-02 | Loss_b: 3.3419e-03
# Step: 4000 | Loss: 1.6051e-02 | Loss_d: 1.7800e-02 | Loss_e: 1.7051e-02 | Loss_b: 3.1260e-03
# Step: 4100 | Loss: 1.4441e-02 | Loss_d: 1.5908e-02 | Loss_e: 1.6964e-02 | Loss_b: 3.0672e-03
# Step: 4200 | Loss: 1.4251e-02 | Loss_d: 1.5621e-02 | Loss_e: 1.7335e-02 | Loss_b: 3.5084e-03
# Step: 4300 | Loss: 1.4640e-02 | Loss_d: 1.6213e-02 | Loss_e: 1.5946e-02 | Loss_b: 2.8730e-03
# Step: 4400 | Loss: 1.4294e-02 | Loss_d: 1.5789e-02 | Loss_e: 1.6109e-02 | Loss_b: 2.9500e-03
# Step: 4500 | Loss: 1.5687e-02 | Loss_d: 1.7542e-02 | Loss_e: 1.5375e-02 | Loss_b: 2.2437e-03
# Step: 4600 | Loss: 1.4507e-02 | Loss_d: 1.5977e-02 | Loss_e: 1.6678e-02 | Loss_b: 3.2916e-03
# Step: 4700 | Loss: 1.3127e-02 | Loss_d: 1.4404e-02 | Loss_e: 1.6618e-02 | Loss_b: 2.7535e-03
# Step: 4800 | Loss: 1.4379e-02 | Loss_d: 1.6019e-02 | Loss_e: 1.5138e-02 | Loss_b: 2.1324e-03
# Step: 4900 | Loss: 1.3105e-02 | Loss_d: 1.4421e-02 | Loss_e: 1.4903e-02 | Loss_b: 3.1841e-03
# Step: 5000 | Loss: 1.4650e-02 | Loss_d: 1.6278e-02 | Loss_e: 1.5941e-02 | Loss_b: 2.3545e-03
# Step: 5100 | Loss: 1.3630e-02 | Loss_d: 1.5027e-02 | Loss_e: 1.6050e-02 | Loss_b: 2.7486e-03
# Step: 5200 | Loss: 1.4750e-02 | Loss_d: 1.6266e-02 | Loss_e: 1.7165e-02 | Loss_b: 3.0321e-03
# Step: 5300 | Loss: 1.4542e-02 | Loss_d: 1.6114e-02 | Loss_e: 1.5956e-02 | Loss_b: 2.6978e-03
# Step: 5400 | Loss: 1.4144e-02 | Loss_d: 1.5552e-02 | Loss_e: 1.6336e-02 | Loss_b: 3.4325e-03
# Step: 5500 | Loss: 1.2766e-02 | Loss_d: 1.4095e-02 | Loss_e: 1.4787e-02 | Loss_b: 2.4820e-03
# Step: 5600 | Loss: 1.4373e-02 | Loss_d: 1.5963e-02 | Loss_e: 1.5661e-02 | Loss_b: 2.3565e-03
# Step: 5700 | Loss: 1.5463e-02 | Loss_d: 1.7291e-02 | Loss_e: 1.3776e-02 | Loss_b: 2.9041e-03
# Step: 5800 | Loss: 1.3901e-02 | Loss_d: 1.5420e-02 | Loss_e: 1.4019e-02 | Loss_b: 3.0387e-03
# Step: 5900 | Loss: 1.2728e-02 | Loss_d: 1.4087e-02 | Loss_e: 1.3961e-02 | Loss_b: 2.5429e-03
# Step: 6000 | Loss: 1.3951e-02 | Loss_d: 1.5421e-02 | Loss_e: 1.6122e-02 | Loss_b: 2.5704e-03
# Step: 6100 | Loss: 1.3561e-02 | Loss_d: 1.4913e-02 | Loss_e: 1.7840e-02 | Loss_b: 2.1780e-03
# Step: 6200 | Loss: 1.1735e-02 | Loss_d: 1.2856e-02 | Loss_e: 1.4949e-02 | Loss_b: 2.6239e-03
# Step: 6300 | Loss: 1.4040e-02 | Loss_d: 1.5572e-02 | Loss_e: 1.4495e-02 | Loss_b: 2.9277e-03
# Step: 6400 | Loss: 1.3210e-02 | Loss_d: 1.4645e-02 | Loss_e: 1.4731e-02 | Loss_b: 2.2620e-03
# Step: 6500 | Loss: 1.2965e-02 | Loss_d: 1.4362e-02 | Loss_e: 1.4128e-02 | Loss_b: 2.5049e-03
# Step: 6600 | Loss: 1.3153e-02 | Loss_d: 1.4588e-02 | Loss_e: 1.4969e-02 | Loss_b: 2.0429e-03
# Step: 6700 | Loss: 1.2584e-02 | Loss_d: 1.3933e-02 | Loss_e: 1.3540e-02 | Loss_b: 2.5748e-03
# Step: 6800 | Loss: 1.2675e-02 | Loss_d: 1.4068e-02 | Loss_e: 1.3687e-02 | Loss_b: 2.2349e-03
# Step: 6900 | Loss: 1.3654e-02 | Loss_d: 1.4990e-02 | Loss_e: 1.7173e-02 | Loss_b: 2.8405e-03
# Step: 7000 | Loss: 1.2334e-02 | Loss_d: 1.3535e-02 | Loss_e: 1.5879e-02 | Loss_b: 2.4467e-03
# Step: 7100 | Loss: 1.3141e-02 | Loss_d: 1.4350e-02 | Loss_e: 1.6598e-02 | Loss_b: 3.4681e-03
# Step: 7200 | Loss: 1.3328e-02 | Loss_d: 1.4815e-02 | Loss_e: 1.3970e-02 | Loss_b: 2.3453e-03
# Step: 7300 | Loss: 1.2546e-02 | Loss_d: 1.3750e-02 | Loss_e: 1.6094e-02 | Loss_b: 2.6914e-03
# Step: 7400 | Loss: 1.2247e-02 | Loss_d: 1.3402e-02 | Loss_e: 1.6696e-02 | Loss_b: 2.3348e-03
# Step: 7500 | Loss: 1.3136e-02 | Loss_d: 1.4327e-02 | Loss_e: 1.9340e-02 | Loss_b: 2.2715e-03
# Step: 7600 | Loss: 1.2392e-02 | Loss_d: 1.3616e-02 | Loss_e: 1.5358e-02 | Loss_b: 2.5772e-03
# Step: 7700 | Loss: 1.2866e-02 | Loss_d: 1.4172e-02 | Loss_e: 1.4198e-02 | Loss_b: 3.1966e-03
# Step: 7800 | Loss: 1.1714e-02 | Loss_d: 1.2871e-02 | Loss_e: 1.4984e-02 | Loss_b: 2.2065e-03
# Step: 7900 | Loss: 1.2297e-02 | Loss_d: 1.3553e-02 | Loss_e: 1.4230e-02 | Loss_b: 2.6516e-03
# Step: 8000 | Loss: 1.2685e-02 | Loss_d: 1.4002e-02 | Loss_e: 1.4890e-02 | Loss_b: 2.4132e-03
# Step: 8100 | Loss: 1.2321e-02 | Loss_d: 1.3522e-02 | Loss_e: 1.6019e-02 | Loss_b: 2.3457e-03
# Step: 8200 | Loss: 1.2164e-02 | Loss_d: 1.3396e-02 | Loss_e: 1.4898e-02 | Loss_b: 2.3177e-03
# Step: 8300 | Loss: 1.2310e-02 | Loss_d: 1.3463e-02 | Loss_e: 1.5299e-02 | Loss_b: 3.1681e-03
# Step: 8400 | Loss: 1.2851e-02 | Loss_d: 1.4187e-02 | Loss_e: 1.5119e-02 | Loss_b: 2.4175e-03
# Step: 8500 | Loss: 1.2312e-02 | Loss_d: 1.3686e-02 | Loss_e: 1.2878e-02 | Loss_b: 2.1776e-03
# Step: 8600 | Loss: 1.2158e-02 | Loss_d: 1.3121e-02 | Loss_e: 1.9263e-02 | Loss_b: 2.8043e-03
# Step: 8700 | Loss: 1.3134e-02 | Loss_d: 1.4401e-02 | Loss_e: 1.8682e-02 | Loss_b: 1.8335e-03
# Step: 8800 | Loss: 1.2938e-02 | Loss_d: 1.4355e-02 | Loss_e: 1.3310e-02 | Loss_b: 2.6682e-03
# Step: 8900 | Loss: 1.3113e-02 | Loss_d: 1.4537e-02 | Loss_e: 1.4739e-02 | Loss_b: 2.1980e-03
# Step: 9000 | Loss: 1.1872e-02 | Loss_d: 1.3074e-02 | Loss_e: 1.4196e-02 | Loss_b: 2.4346e-03
# Step: 9100 | Loss: 1.1042e-02 | Loss_d: 1.2161e-02 | Loss_e: 1.3758e-02 | Loss_b: 1.9798e-03
# Step: 9200 | Loss: 1.2094e-02 | Loss_d: 1.3416e-02 | Loss_e: 1.3246e-02 | Loss_b: 2.1113e-03
# Step: 9300 | Loss: 1.2460e-02 | Loss_d: 1.3825e-02 | Loss_e: 1.2609e-02 | Loss_b: 2.6584e-03
# Step: 9400 | Loss: 1.2028e-02 | Loss_d: 1.3151e-02 | Loss_e: 1.6691e-02 | Loss_b: 2.2587e-03
# Step: 9500 | Loss: 1.1173e-02 | Loss_d: 1.2188e-02 | Loss_e: 1.5103e-02 | Loss_b: 2.5754e-03
# Step: 9600 | Loss: 1.2432e-02 | Loss_d: 1.3786e-02 | Loss_e: 1.4454e-02 | Loss_b: 1.7979e-03
# Step: 9700 | Loss: 1.1201e-02 | Loss_d: 1.2279e-02 | Loss_e: 1.5220e-02 | Loss_b: 1.9487e-03
# Step: 9800 | Loss: 1.1675e-02 | Loss_d: 1.2947e-02 | Loss_e: 1.2404e-02 | Loss_b: 2.2670e-03
# Step: 9900 | Loss: 1.2259e-02 | Loss_d: 1.3763e-02 | Loss_e: 1.1219e-02 | Loss_b: 1.6081e-03
# Step: 10000 | Loss: 1.1517e-02 | Loss_d: 1.2699e-02 | Loss_e: 1.4194e-02 | Loss_b: 1.9882e-03

# %%
# # set the training iteration
# epoch2 = 10000
# # re-sample the data and collocation points
# data_l = dataf_l(key_lbfgs[1])

# # training with L-bfgs
# trained_params2, loss2 = lbfgs_opt(NN_loss, trained_params, data_l, epoch2)
# Out:
# Streaming output truncated to the last 5000 lines.
# Step: NaN | Loss: 8.8353e-03 | Loss_d: 9.8438e-03 Loss_e: 8.8162e-03 | Loss_b: 1.5465e-03
# Step: NaN | Loss: 8.8396e-03 | Loss_d: 9.8430e-03 Loss_e: 8.9102e-03 | Loss_b: 1.5584e-03
# Step: NaN | Loss: 8.8352e-03 | Loss_d: 9.8435e-03 Loss_e: 8.8179e-03 | Loss_b: 1.5478e-03
# Step: NaN | Loss: 8.8346e-03 | Loss_d: 9.8435e-03 Loss_e: 8.8094e-03 | Loss_b: 1.5441e-03
# Step: NaN | Loss: 8.8357e-03 | Loss_d: 9.8448e-03 Loss_e: 8.8396e-03 | Loss_b: 1.5294e-03
# Step: NaN | Loss: 8.8343e-03 | Loss_d: 9.8437e-03 Loss_e: 8.8079e-03 | Loss_b: 1.5395e-03
# Step: NaN | Loss: 8.8335e-03 | Loss_d: 9.8429e-03 Loss_e: 8.8195e-03 | Loss_b: 1.5326e-03
# Step: NaN | Loss: 8.8353e-03 | Loss_d: 9.8418e-03 Loss_e: 8.9367e-03 | Loss_b: 1.5053e-03
# Step: NaN | Loss: 8.8333e-03 | Loss_d: 9.8423e-03 Loss_e: 8.8404e-03 | Loss_b: 1.5250e-03
# Step: NaN | Loss: 8.8325e-03 | Loss_d: 9.8418e-03 Loss_e: 8.8340e-03 | Loss_b: 1.5239e-03
# Step: NaN | Loss: 8.8352e-03 | Loss_d: 9.8413e-03 Loss_e: 8.9179e-03 | Loss_b: 1.5196e-03
# Step: NaN | Loss: 8.8323e-03 | Loss_d: 9.8416e-03 Loss_e: 8.8369e-03 | Loss_b: 1.5230e-03
# Step: NaN | Loss: 8.8315e-03 | Loss_d: 9.8420e-03 Loss_e: 8.8246e-03 | Loss_b: 1.5153e-03
# Step: NaN | Loss: 8.8396e-03 | Loss_d: 9.8484e-03 Loss_e: 8.9443e-03 | Loss_b: 1.4865e-03
# Step: NaN | Loss: 8.8315e-03 | Loss_d: 9.8422e-03 Loss_e: 8.8242e-03 | Loss_b: 1.5138e-03
# Step: NaN | Loss: 8.8311e-03 | Loss_d: 9.8412e-03 Loss_e: 8.8397e-03 | Loss_b: 1.5110e-03
# Step: NaN | Loss: 8.8319e-03 | Loss_d: 9.8374e-03 Loss_e: 8.9552e-03 | Loss_b: 1.5000e-03
# Step: NaN | Loss: 8.8309e-03 | Loss_d: 9.8400e-03 Loss_e: 8.8654e-03 | Loss_b: 1.5077e-03
# Step: NaN | Loss: 8.8305e-03 | Loss_d: 9.8390e-03 Loss_e: 8.8702e-03 | Loss_b: 1.5104e-03
# Step: NaN | Loss: 8.8326e-03 | Loss_d: 9.8368e-03 Loss_e: 8.9423e-03 | Loss_b: 1.5212e-03
# Step: NaN | Loss: 8.8305e-03 | Loss_d: 9.8386e-03 Loss_e: 8.8750e-03 | Loss_b: 1.5118e-03
# Step: NaN | Loss: 8.8301e-03 | Loss_d: 9.8383e-03 Loss_e: 8.8657e-03 | Loss_b: 1.5150e-03
# Step: NaN | Loss: 8.8301e-03 | Loss_d: 9.8378e-03 Loss_e: 8.8498e-03 | Loss_b: 1.5278e-03
# Step: NaN | Loss: 8.8298e-03 | Loss_d: 9.8380e-03 Loss_e: 8.8530e-03 | Loss_b: 1.5218e-03
# Step: NaN | Loss: 8.8293e-03 | Loss_d: 9.8373e-03 Loss_e: 8.8493e-03 | Loss_b: 1.5243e-03
# Step: NaN | Loss: 8.8294e-03 | Loss_d: 9.8354e-03 Loss_e: 8.8696e-03 | Loss_b: 1.5342e-03
# Step: NaN | Loss: 8.8289e-03 | Loss_d: 9.8362e-03 Loss_e: 8.8520e-03 | Loss_b: 1.5290e-03
# Step: NaN | Loss: 8.8283e-03 | Loss_d: 9.8347e-03 Loss_e: 8.8637e-03 | Loss_b: 1.5317e-03
# Step: NaN | Loss: 8.8307e-03 | Loss_d: 9.8298e-03 Loss_e: 8.9967e-03 | Loss_b: 1.5427e-03
# Step: NaN | Loss: 8.8282e-03 | Loss_d: 9.8336e-03 Loss_e: 8.8780e-03 | Loss_b: 1.5337e-03
# Step: NaN | Loss: 8.8276e-03 | Loss_d: 9.8334e-03 Loss_e: 8.8674e-03 | Loss_b: 1.5331e-03
# Step: NaN | Loss: 8.8316e-03 | Loss_d: 9.8353e-03 Loss_e: 8.9309e-03 | Loss_b: 1.5308e-03
# Step: NaN | Loss: 8.8275e-03 | Loss_d: 9.8334e-03 Loss_e: 8.8661e-03 | Loss_b: 1.5328e-03
# Step: NaN | Loss: 8.8271e-03 | Loss_d: 9.8328e-03 Loss_e: 8.8733e-03 | Loss_b: 1.5303e-03
# Step: NaN | Loss: 8.8271e-03 | Loss_d: 9.8305e-03 Loss_e: 8.9394e-03 | Loss_b: 1.5201e-03
# Step: NaN | Loss: 8.8267e-03 | Loss_d: 9.8316e-03 Loss_e: 8.8994e-03 | Loss_b: 1.5251e-03
# Step: NaN | Loss: 8.8260e-03 | Loss_d: 9.8309e-03 Loss_e: 8.8953e-03 | Loss_b: 1.5262e-03
# Step: NaN | Loss: 8.8262e-03 | Loss_d: 9.8287e-03 Loss_e: 8.9355e-03 | Loss_b: 1.5307e-03
# Step: NaN | Loss: 8.8255e-03 | Loss_d: 9.8297e-03 Loss_e: 8.9022e-03 | Loss_b: 1.5283e-03
# Step: NaN | Loss: 8.8248e-03 | Loss_d: 9.8307e-03 Loss_e: 8.8567e-03 | Loss_b: 1.5322e-03
# Step: NaN | Loss: 8.8303e-03 | Loss_d: 9.8381e-03 Loss_e: 8.8078e-03 | Loss_b: 1.5484e-03
# Step: NaN | Loss: 8.8247e-03 | Loss_d: 9.8312e-03 Loss_e: 8.8424e-03 | Loss_b: 1.5338e-03
# Step: NaN | Loss: 8.8241e-03 | Loss_d: 9.8312e-03 Loss_e: 8.8300e-03 | Loss_b: 1.5329e-03
# Step: NaN | Loss: 8.8268e-03 | Loss_d: 9.8326e-03 Loss_e: 8.8727e-03 | Loss_b: 1.5296e-03
# Step: NaN | Loss: 8.8239e-03 | Loss_d: 9.8313e-03 Loss_e: 8.8267e-03 | Loss_b: 1.5324e-03
# Step: NaN | Loss: 8.8235e-03 | Loss_d: 9.8313e-03 Loss_e: 8.8025e-03 | Loss_b: 1.5383e-03
# Step: NaN | Loss: 8.8249e-03 | Loss_d: 9.8331e-03 Loss_e: 8.7512e-03 | Loss_b: 1.5626e-03
# Step: NaN | Loss: 8.8233e-03 | Loss_d: 9.8315e-03 Loss_e: 8.7836e-03 | Loss_b: 1.5441e-03
# Step: NaN | Loss: 8.8230e-03 | Loss_d: 9.8308e-03 Loss_e: 8.7849e-03 | Loss_b: 1.5468e-03
# Step: NaN | Loss: 8.8274e-03 | Loss_d: 9.8292e-03 Loss_e: 8.8988e-03 | Loss_b: 1.5581e-03
# Step: NaN | Loss: 8.8230e-03 | Loss_d: 9.8307e-03 Loss_e: 8.7854e-03 | Loss_b: 1.5470e-03
# Step: NaN | Loss: 8.8227e-03 | Loss_d: 9.8307e-03 Loss_e: 8.7812e-03 | Loss_b: 1.5455e-03
# Step: NaN | Loss: 8.8227e-03 | Loss_d: 9.8311e-03 Loss_e: 8.7865e-03 | Loss_b: 1.5395e-03
# Step: NaN | Loss: 8.8224e-03 | Loss_d: 9.8308e-03 Loss_e: 8.7794e-03 | Loss_b: 1.5425e-03
# Step: NaN | Loss: 8.8220e-03 | Loss_d: 9.8303e-03 Loss_e: 8.7794e-03 | Loss_b: 1.5423e-03
# Step: NaN | Loss: 8.8224e-03 | Loss_d: 9.8288e-03 Loss_e: 8.8193e-03 | Loss_b: 1.5418e-03
# Step: NaN | Loss: 8.8217e-03 | Loss_d: 9.8296e-03 Loss_e: 8.7874e-03 | Loss_b: 1.5421e-03
# Step: NaN | Loss: 8.8212e-03 | Loss_d: 9.8288e-03 Loss_e: 8.7845e-03 | Loss_b: 1.5458e-03
# Step: NaN | Loss: 8.8239e-03 | Loss_d: 9.8288e-03 Loss_e: 8.8179e-03 | Loss_b: 1.5608e-03
# Step: NaN | Loss: 8.8211e-03 | Loss_d: 9.8284e-03 Loss_e: 8.7849e-03 | Loss_b: 1.5481e-03
# Step: NaN | Loss: 8.8206e-03 | Loss_d: 9.8283e-03 Loss_e: 8.7779e-03 | Loss_b: 1.5465e-03
# Step: NaN | Loss: 8.8208e-03 | Loss_d: 9.8293e-03 Loss_e: 8.7753e-03 | Loss_b: 1.5402e-03
# Step: NaN | Loss: 8.8203e-03 | Loss_d: 9.8285e-03 Loss_e: 8.7717e-03 | Loss_b: 1.5437e-03
# Step: NaN | Loss: 8.8196e-03 | Loss_d: 9.8279e-03 Loss_e: 8.7636e-03 | Loss_b: 1.5464e-03
# Step: NaN | Loss: 8.8198e-03 | Loss_d: 9.8265e-03 Loss_e: 8.7730e-03 | Loss_b: 1.5575e-03
# Step: NaN | Loss: 8.8192e-03 | Loss_d: 9.8270e-03 Loss_e: 8.7597e-03 | Loss_b: 1.5516e-03
# Step: NaN | Loss: 8.8186e-03 | Loss_d: 9.8275e-03 Loss_e: 8.7080e-03 | Loss_b: 1.5653e-03
# Step: NaN | Loss: 8.8233e-03 | Loss_d: 9.8312e-03 Loss_e: 8.6342e-03 | Loss_b: 1.6216e-03
# Step: NaN | Loss: 8.8185e-03 | Loss_d: 9.8277e-03 Loss_e: 8.6931e-03 | Loss_b: 1.5701e-03
# Step: NaN | Loss: 8.8181e-03 | Loss_d: 9.8278e-03 Loss_e: 8.6752e-03 | Loss_b: 1.5738e-03
# Step: NaN | Loss: 8.8203e-03 | Loss_d: 9.8288e-03 Loss_e: 8.6771e-03 | Loss_b: 1.5885e-03
# Step: NaN | Loss: 8.8180e-03 | Loss_d: 9.8278e-03 Loss_e: 8.6682e-03 | Loss_b: 1.5759e-03
# Step: NaN | Loss: 8.8177e-03 | Loss_d: 9.8270e-03 Loss_e: 8.6737e-03 | Loss_b: 1.5769e-03
# Step: NaN | Loss: 8.8190e-03 | Loss_d: 9.8244e-03 Loss_e: 8.7502e-03 | Loss_b: 1.5812e-03
# Step: NaN | Loss: 8.8176e-03 | Loss_d: 9.8264e-03 Loss_e: 8.6820e-03 | Loss_b: 1.5778e-03
# Step: NaN | Loss: 8.8172e-03 | Loss_d: 9.8267e-03 Loss_e: 8.6713e-03 | Loss_b: 1.5760e-03
# Step: NaN | Loss: 8.8172e-03 | Loss_d: 9.8284e-03 Loss_e: 8.6510e-03 | Loss_b: 1.5688e-03
# Step: NaN | Loss: 8.8169e-03 | Loss_d: 9.8274e-03 Loss_e: 8.6569e-03 | Loss_b: 1.5725e-03
# Step: NaN | Loss: 8.8163e-03 | Loss_d: 9.8269e-03 Loss_e: 8.6678e-03 | Loss_b: 1.5656e-03
# Step: NaN | Loss: 8.8171e-03 | Loss_d: 9.8258e-03 Loss_e: 8.7609e-03 | Loss_b: 1.5386e-03
# Step: NaN | Loss: 8.8160e-03 | Loss_d: 9.8263e-03 Loss_e: 8.6901e-03 | Loss_b: 1.5564e-03
# Step: NaN | Loss: 8.8153e-03 | Loss_d: 9.8264e-03 Loss_e: 8.6763e-03 | Loss_b: 1.5542e-03
# Step: NaN | Loss: 8.8156e-03 | Loss_d: 9.8277e-03 Loss_e: 8.6739e-03 | Loss_b: 1.5455e-03
# Step: NaN | Loss: 8.8148e-03 | Loss_d: 9.8268e-03 Loss_e: 8.6647e-03 | Loss_b: 1.5503e-03
# Step: NaN | Loss: 8.8143e-03 | Loss_d: 9.8282e-03 Loss_e: 8.6353e-03 | Loss_b: 1.5452e-03
# Step: NaN | Loss: 8.8143e-03 | Loss_d: 9.8278e-03 Loss_e: 8.6393e-03 | Loss_b: 1.5464e-03
# Step: NaN | Loss: 8.8139e-03 | Loss_d: 9.8275e-03 Loss_e: 8.6384e-03 | Loss_b: 1.5451e-03
# Step: NaN | Loss: 8.8150e-03 | Loss_d: 9.8270e-03 Loss_e: 8.6857e-03 | Loss_b: 1.5399e-03
# Step: NaN | Loss: 8.8137e-03 | Loss_d: 9.8272e-03 Loss_e: 8.6429e-03 | Loss_b: 1.5437e-03
# Step: NaN | Loss: 8.8133e-03 | Loss_d: 9.8267e-03 Loss_e: 8.6433e-03 | Loss_b: 1.5440e-03
# Step: NaN | Loss: 8.8134e-03 | Loss_d: 9.8250e-03 Loss_e: 8.6756e-03 | Loss_b: 1.5452e-03
# Step: NaN | Loss: 8.8130e-03 | Loss_d: 9.8258e-03 Loss_e: 8.6531e-03 | Loss_b: 1.5446e-03
# Step: NaN | Loss: 8.8124e-03 | Loss_d: 9.8256e-03 Loss_e: 8.6383e-03 | Loss_b: 1.5475e-03
# Step: NaN | Loss: 8.8140e-03 | Loss_d: 9.8263e-03 Loss_e: 8.6355e-03 | Loss_b: 1.5596e-03
# Step: NaN | Loss: 8.8122e-03 | Loss_d: 9.8255e-03 Loss_e: 8.6292e-03 | Loss_b: 1.5505e-03
# Step: NaN | Loss: 8.8117e-03 | Loss_d: 9.8254e-03 Loss_e: 8.6101e-03 | Loss_b: 1.5541e-03
# Step: NaN | Loss: 8.8138e-03 | Loss_d: 9.8263e-03 Loss_e: 8.6115e-03 | Loss_b: 1.5690e-03
# Step: NaN | Loss: 8.8115e-03 | Loss_d: 9.8254e-03 Loss_e: 8.6003e-03 | Loss_b: 1.5570e-03
# Step: NaN | Loss: 8.8110e-03 | Loss_d: 9.8253e-03 Loss_e: 8.5984e-03 | Loss_b: 1.5532e-03
# Step: NaN | Loss: 8.8123e-03 | Loss_d: 9.8257e-03 Loss_e: 8.6509e-03 | Loss_b: 1.5383e-03
# Step: NaN | Loss: 8.8109e-03 | Loss_d: 9.8253e-03 Loss_e: 8.6025e-03 | Loss_b: 1.5495e-03
# Step: NaN | Loss: 8.8104e-03 | Loss_d: 9.8248e-03 Loss_e: 8.5980e-03 | Loss_b: 1.5513e-03
# Step: NaN | Loss: 8.8104e-03 | Loss_d: 9.8236e-03 Loss_e: 8.6081e-03 | Loss_b: 1.5584e-03
# Step: NaN | Loss: 8.8100e-03 | Loss_d: 9.8240e-03 Loss_e: 8.5976e-03 | Loss_b: 1.5550e-03
# Step: NaN | Loss: 8.8093e-03 | Loss_d: 9.8234e-03 Loss_e: 8.6113e-03 | Loss_b: 1.5460e-03
# Step: NaN | Loss: 8.8104e-03 | Loss_d: 9.8222e-03 Loss_e: 8.7292e-03 | Loss_b: 1.5114e-03
# Step: NaN | Loss: 8.8090e-03 | Loss_d: 9.8228e-03 Loss_e: 8.6389e-03 | Loss_b: 1.5344e-03
# Step: NaN | Loss: 8.8084e-03 | Loss_d: 9.8224e-03 Loss_e: 8.6390e-03 | Loss_b: 1.5317e-03
# Step: NaN | Loss: 8.8145e-03 | Loss_d: 9.8258e-03 Loss_e: 8.7362e-03 | Loss_b: 1.5210e-03
# Step: NaN | Loss: 8.8084e-03 | Loss_d: 9.8224e-03 Loss_e: 8.6399e-03 | Loss_b: 1.5313e-03
# Step: NaN | Loss: 8.8079e-03 | Loss_d: 9.8217e-03 Loss_e: 8.6365e-03 | Loss_b: 1.5343e-03
# Step: NaN | Loss: 8.8085e-03 | Loss_d: 9.8195e-03 Loss_e: 8.6679e-03 | Loss_b: 1.5461e-03
# Step: NaN | Loss: 8.8077e-03 | Loss_d: 9.8208e-03 Loss_e: 8.6396e-03 | Loss_b: 1.5386e-03
# Step: NaN | Loss: 8.8070e-03 | Loss_d: 9.8211e-03 Loss_e: 8.6081e-03 | Loss_b: 1.5431e-03
# Step: NaN | Loss: 8.8085e-03 | Loss_d: 9.8237e-03 Loss_e: 8.5558e-03 | Loss_b: 1.5611e-03
# Step: NaN | Loss: 8.8067e-03 | Loss_d: 9.8216e-03 Loss_e: 8.5815e-03 | Loss_b: 1.5481e-03
# Step: NaN | Loss: 8.8061e-03 | Loss_d: 9.8206e-03 Loss_e: 8.5732e-03 | Loss_b: 1.5553e-03
# Step: NaN | Loss: 8.8076e-03 | Loss_d: 9.8174e-03 Loss_e: 8.6108e-03 | Loss_b: 1.5851e-03
# Step: NaN | Loss: 8.8059e-03 | Loss_d: 9.8197e-03 Loss_e: 8.5720e-03 | Loss_b: 1.5628e-03
# Step: NaN | Loss: 8.8054e-03 | Loss_d: 9.8187e-03 Loss_e: 8.5652e-03 | Loss_b: 1.5694e-03
# Step: NaN | Loss: 8.8069e-03 | Loss_d: 9.8158e-03 Loss_e: 8.6071e-03 | Loss_b: 1.5960e-03
# Step: NaN | Loss: 8.8052e-03 | Loss_d: 9.8179e-03 Loss_e: 8.5651e-03 | Loss_b: 1.5756e-03
# Step: NaN | Loss: 8.8048e-03 | Loss_d: 9.8175e-03 Loss_e: 8.5577e-03 | Loss_b: 1.5786e-03
# Step: NaN | Loss: 8.8048e-03 | Loss_d: 9.8175e-03 Loss_e: 8.5576e-03 | Loss_b: 1.5784e-03
# Step: NaN | Loss: 8.8046e-03 | Loss_d: 9.8166e-03 Loss_e: 8.5703e-03 | Loss_b: 1.5778e-03
# Step: NaN | Loss: 8.8041e-03 | Loss_d: 9.8133e-03 Loss_e: 8.6310e-03 | Loss_b: 1.5754e-03
# Step: NaN | Loss: 8.8041e-03 | Loss_d: 9.8135e-03 Loss_e: 8.6283e-03 | Loss_b: 1.5755e-03
# Step: NaN | Loss: 8.8036e-03 | Loss_d: 9.8124e-03 Loss_e: 8.6309e-03 | Loss_b: 1.5785e-03
# Step: NaN | Loss: 8.8057e-03 | Loss_d: 9.8091e-03 Loss_e: 8.7222e-03 | Loss_b: 1.5909e-03
# Step: NaN | Loss: 8.8034e-03 | Loss_d: 9.8116e-03 Loss_e: 8.6385e-03 | Loss_b: 1.5809e-03
# Step: NaN | Loss: 8.8031e-03 | Loss_d: 9.8117e-03 Loss_e: 8.6286e-03 | Loss_b: 1.5800e-03
# Step: NaN | Loss: 8.8067e-03 | Loss_d: 9.8149e-03 Loss_e: 8.6556e-03 | Loss_b: 1.5775e-03
# Step: NaN | Loss: 8.8030e-03 | Loss_d: 9.8118e-03 Loss_e: 8.6272e-03 | Loss_b: 1.5798e-03
# Step: NaN | Loss: 8.8027e-03 | Loss_d: 9.8114e-03 Loss_e: 8.6285e-03 | Loss_b: 1.5796e-03
# Step: NaN | Loss: 8.8027e-03 | Loss_d: 9.8102e-03 Loss_e: 8.6523e-03 | Loss_b: 1.5792e-03
# Step: NaN | Loss: 8.8025e-03 | Loss_d: 9.8107e-03 Loss_e: 8.6364e-03 | Loss_b: 1.5794e-03
# Step: NaN | Loss: 8.8021e-03 | Loss_d: 9.8103e-03 Loss_e: 8.6385e-03 | Loss_b: 1.5787e-03
# Step: NaN | Loss: 8.8023e-03 | Loss_d: 9.8090e-03 Loss_e: 8.6717e-03 | Loss_b: 1.5758e-03
# Step: NaN | Loss: 8.8019e-03 | Loss_d: 9.8096e-03 Loss_e: 8.6483e-03 | Loss_b: 1.5774e-03
# Step: NaN | Loss: 8.8014e-03 | Loss_d: 9.8095e-03 Loss_e: 8.6342e-03 | Loss_b: 1.5791e-03
# Step: NaN | Loss: 8.8033e-03 | Loss_d: 9.8104e-03 Loss_e: 8.6483e-03 | Loss_b: 1.5861e-03
# Step: NaN | Loss: 8.8012e-03 | Loss_d: 9.8095e-03 Loss_e: 8.6279e-03 | Loss_b: 1.5805e-03
# Step: NaN | Loss: 8.8007e-03 | Loss_d: 9.8088e-03 Loss_e: 8.6384e-03 | Loss_b: 1.5763e-03
# Step: NaN | Loss: 8.8023e-03 | Loss_d: 9.8069e-03 Loss_e: 8.7463e-03 | Loss_b: 1.5600e-03
# Step: NaN | Loss: 8.8006e-03 | Loss_d: 9.8083e-03 Loss_e: 8.6535e-03 | Loss_b: 1.5726e-03
# Step: NaN | Loss: 8.8001e-03 | Loss_d: 9.8081e-03 Loss_e: 8.6389e-03 | Loss_b: 1.5763e-03
# Step: NaN | Loss: 8.8008e-03 | Loss_d: 9.8079e-03 Loss_e: 8.6278e-03 | Loss_b: 1.5919e-03
# Step: NaN | Loss: 8.7999e-03 | Loss_d: 9.8079e-03 Loss_e: 8.6268e-03 | Loss_b: 1.5814e-03
# Step: NaN | Loss: 8.7994e-03 | Loss_d: 9.8073e-03 Loss_e: 8.6254e-03 | Loss_b: 1.5833e-03
# Step: NaN | Loss: 8.8020e-03 | Loss_d: 9.8061e-03 Loss_e: 8.6943e-03 | Loss_b: 1.5909e-03
# Step: NaN | Loss: 8.7994e-03 | Loss_d: 9.8070e-03 Loss_e: 8.6278e-03 | Loss_b: 1.5843e-03
# Step: NaN | Loss: 8.7989e-03 | Loss_d: 9.8071e-03 Loss_e: 8.6190e-03 | Loss_b: 1.5823e-03
# Step: NaN | Loss: 8.8004e-03 | Loss_d: 9.8083e-03 Loss_e: 8.6449e-03 | Loss_b: 1.5745e-03
# Step: NaN | Loss: 8.7988e-03 | Loss_d: 9.8072e-03 Loss_e: 8.6163e-03 | Loss_b: 1.5806e-03
# Step: NaN | Loss: 8.7983e-03 | Loss_d: 9.8068e-03 Loss_e: 8.6087e-03 | Loss_b: 1.5830e-03
# Step: NaN | Loss: 8.7981e-03 | Loss_d: 9.8056e-03 Loss_e: 8.6105e-03 | Loss_b: 1.5926e-03
# Step: NaN | Loss: 8.7979e-03 | Loss_d: 9.8060e-03 Loss_e: 8.6034e-03 | Loss_b: 1.5883e-03
# Step: NaN | Loss: 8.7973e-03 | Loss_d: 9.8056e-03 Loss_e: 8.5961e-03 | Loss_b: 1.5900e-03
# Step: NaN | Loss: 8.7998e-03 | Loss_d: 9.8059e-03 Loss_e: 8.6358e-03 | Loss_b: 1.5966e-03
# Step: NaN | Loss: 8.7972e-03 | Loss_d: 9.8054e-03 Loss_e: 8.5951e-03 | Loss_b: 1.5911e-03
# Step: NaN | Loss: 8.7966e-03 | Loss_d: 9.8063e-03 Loss_e: 8.5590e-03 | Loss_b: 1.5933e-03
# Step: NaN | Loss: 8.8024e-03 | Loss_d: 9.8119e-03 Loss_e: 8.5632e-03 | Loss_b: 1.6024e-03
# Step: NaN | Loss: 8.7966e-03 | Loss_d: 9.8065e-03 Loss_e: 8.5534e-03 | Loss_b: 1.5938e-03
# Step: NaN | Loss: 8.7962e-03 | Loss_d: 9.8064e-03 Loss_e: 8.5392e-03 | Loss_b: 1.5971e-03
# Step: NaN | Loss: 8.7959e-03 | Loss_d: 9.8062e-03 Loss_e: 8.5073e-03 | Loss_b: 1.6106e-03
# Step: NaN | Loss: 8.7957e-03 | Loss_d: 9.8062e-03 Loss_e: 8.5141e-03 | Loss_b: 1.6058e-03
# Step: NaN | Loss: 8.7952e-03 | Loss_d: 9.8062e-03 Loss_e: 8.5100e-03 | Loss_b: 1.6013e-03
# Step: NaN | Loss: 8.7964e-03 | Loss_d: 9.8077e-03 Loss_e: 8.5420e-03 | Loss_b: 1.5839e-03
# Step: NaN | Loss: 8.7949e-03 | Loss_d: 9.8064e-03 Loss_e: 8.5112e-03 | Loss_b: 1.5964e-03
# Step: NaN | Loss: 8.7943e-03 | Loss_d: 9.8056e-03 Loss_e: 8.5148e-03 | Loss_b: 1.5955e-03
# Step: NaN | Loss: 8.7946e-03 | Loss_d: 9.8033e-03 Loss_e: 8.5743e-03 | Loss_b: 1.5919e-03
# Step: NaN | Loss: 8.7939e-03 | Loss_d: 9.8044e-03 Loss_e: 8.5318e-03 | Loss_b: 1.5939e-03
# Step: NaN | Loss: 8.7935e-03 | Loss_d: 9.8052e-03 Loss_e: 8.5092e-03 | Loss_b: 1.5913e-03
# Step: NaN | Loss: 8.7934e-03 | Loss_d: 9.8050e-03 Loss_e: 8.5126e-03 | Loss_b: 1.5919e-03
# Step: NaN | Loss: 8.7931e-03 | Loss_d: 9.8052e-03 Loss_e: 8.4974e-03 | Loss_b: 1.5930e-03
# Step: NaN | Loss: 8.7926e-03 | Loss_d: 9.8063e-03 Loss_e: 8.4539e-03 | Loss_b: 1.5977e-03
# Step: NaN | Loss: 8.7926e-03 | Loss_d: 9.8061e-03 Loss_e: 8.4593e-03 | Loss_b: 1.5969e-03
# Step: NaN | Loss: 8.7920e-03 | Loss_d: 9.8052e-03 Loss_e: 8.4661e-03 | Loss_b: 1.5959e-03
# Step: NaN | Loss: 8.7954e-03 | Loss_d: 9.8033e-03 Loss_e: 8.5906e-03 | Loss_b: 1.5919e-03
# Step: NaN | Loss: 8.7919e-03 | Loss_d: 9.8048e-03 Loss_e: 8.4734e-03 | Loss_b: 1.5953e-03
# Step: NaN | Loss: 8.7915e-03 | Loss_d: 9.8045e-03 Loss_e: 8.4603e-03 | Loss_b: 1.5994e-03
# Step: NaN | Loss: 8.7927e-03 | Loss_d: 9.8042e-03 Loss_e: 8.4623e-03 | Loss_b: 1.6160e-03
# Step: NaN | Loss: 8.7913e-03 | Loss_d: 9.8043e-03 Loss_e: 8.4526e-03 | Loss_b: 1.6036e-03
# Step: NaN | Loss: 8.7908e-03 | Loss_d: 9.8038e-03 Loss_e: 8.4562e-03 | Loss_b: 1.6004e-03
# Step: NaN | Loss: 8.7915e-03 | Loss_d: 9.8026e-03 Loss_e: 8.5218e-03 | Loss_b: 1.5881e-03
# Step: NaN | Loss: 8.7906e-03 | Loss_d: 9.8033e-03 Loss_e: 8.4689e-03 | Loss_b: 1.5962e-03
# Step: NaN | Loss: 8.7900e-03 | Loss_d: 9.8027e-03 Loss_e: 8.4702e-03 | Loss_b: 1.5948e-03
# Step: NaN | Loss: 8.7912e-03 | Loss_d: 9.8013e-03 Loss_e: 8.5385e-03 | Loss_b: 1.5891e-03
# Step: NaN | Loss: 8.7898e-03 | Loss_d: 9.8022e-03 Loss_e: 8.4792e-03 | Loss_b: 1.5931e-03
# Step: NaN | Loss: 8.7892e-03 | Loss_d: 9.8014e-03 Loss_e: 8.4761e-03 | Loss_b: 1.5959e-03
# Step: NaN | Loss: 8.7936e-03 | Loss_d: 9.8005e-03 Loss_e: 8.5737e-03 | Loss_b: 1.6072e-03
# Step: NaN | Loss: 8.7892e-03 | Loss_d: 9.8012e-03 Loss_e: 8.4777e-03 | Loss_b: 1.5969e-03
# Step: NaN | Loss: 8.7887e-03 | Loss_d: 9.8017e-03 Loss_e: 8.4571e-03 | Loss_b: 1.5958e-03
# Step: NaN | Loss: 8.7891e-03 | Loss_d: 9.8047e-03 Loss_e: 8.4165e-03 | Loss_b: 1.5913e-03
# Step: NaN | Loss: 8.7884e-03 | Loss_d: 9.8028e-03 Loss_e: 8.4334e-03 | Loss_b: 1.5940e-03
# Step: NaN | Loss: 8.7879e-03 | Loss_d: 9.8017e-03 Loss_e: 8.4451e-03 | Loss_b: 1.5928e-03
# Step: NaN | Loss: 8.7902e-03 | Loss_d: 9.7987e-03 Loss_e: 8.5682e-03 | Loss_b: 1.5887e-03
# Step: NaN | Loss: 8.7878e-03 | Loss_d: 9.8011e-03 Loss_e: 8.4571e-03 | Loss_b: 1.5921e-03
# Step: NaN | Loss: 8.7874e-03 | Loss_d: 9.8011e-03 Loss_e: 8.4484e-03 | Loss_b: 1.5920e-03
# Step: NaN | Loss: 8.7917e-03 | Loss_d: 9.8017e-03 Loss_e: 8.5377e-03 | Loss_b: 1.5917e-03
# Step: NaN | Loss: 8.7874e-03 | Loss_d: 9.8011e-03 Loss_e: 8.4482e-03 | Loss_b: 1.5920e-03
# Step: NaN | Loss: 8.7871e-03 | Loss_d: 9.8010e-03 Loss_e: 8.4386e-03 | Loss_b: 1.5939e-03
# Step: NaN | Loss: 8.7869e-03 | Loss_d: 9.8011e-03 Loss_e: 8.4170e-03 | Loss_b: 1.6015e-03
# Step: NaN | Loss: 8.7868e-03 | Loss_d: 9.8010e-03 Loss_e: 8.4218e-03 | Loss_b: 1.5986e-03
# Step: NaN | Loss: 8.7864e-03 | Loss_d: 9.8007e-03 Loss_e: 8.4150e-03 | Loss_b: 1.6010e-03
# Step: NaN | Loss: 8.7866e-03 | Loss_d: 9.7995e-03 Loss_e: 8.4218e-03 | Loss_b: 1.6107e-03
# Step: NaN | Loss: 8.7862e-03 | Loss_d: 9.8001e-03 Loss_e: 8.4112e-03 | Loss_b: 1.6053e-03
# Step: NaN | Loss: 8.7855e-03 | Loss_d: 9.7997e-03 Loss_e: 8.3962e-03 | Loss_b: 1.6099e-03
# Step: NaN | Loss: 8.7858e-03 | Loss_d: 9.7987e-03 Loss_e: 8.3842e-03 | Loss_b: 1.6282e-03
# Step: NaN | Loss: 8.7851e-03 | Loss_d: 9.7990e-03 Loss_e: 8.3812e-03 | Loss_b: 1.6181e-03
# Step: NaN | Loss: 8.7847e-03 | Loss_d: 9.7993e-03 Loss_e: 8.3763e-03 | Loss_b: 1.6131e-03
# Step: NaN | Loss: 8.7846e-03 | Loss_d: 9.7992e-03 Loss_e: 8.3751e-03 | Loss_b: 1.6146e-03
# Step: NaN | Loss: 8.7843e-03 | Loss_d: 9.7988e-03 Loss_e: 8.3799e-03 | Loss_b: 1.6125e-03
# Step: NaN | Loss: 8.7841e-03 | Loss_d: 9.7977e-03 Loss_e: 8.4123e-03 | Loss_b: 1.6043e-03
# Step: NaN | Loss: 8.7840e-03 | Loss_d: 9.7979e-03 Loss_e: 8.3994e-03 | Loss_b: 1.6069e-03
# Step: NaN | Loss: 8.7835e-03 | Loss_d: 9.7973e-03 Loss_e: 8.4002e-03 | Loss_b: 1.6070e-03
# Step: NaN | Loss: 8.7839e-03 | Loss_d: 9.7953e-03 Loss_e: 8.4479e-03 | Loss_b: 1.6073e-03
# Step: NaN | Loss: 8.7832e-03 | Loss_d: 9.7964e-03 Loss_e: 8.4107e-03 | Loss_b: 1.6071e-03
# Step: NaN | Loss: 8.7826e-03 | Loss_d: 9.7954e-03 Loss_e: 8.4300e-03 | Loss_b: 1.6001e-03
# Step: NaN | Loss: 8.7842e-03 | Loss_d: 9.7930e-03 Loss_e: 8.5717e-03 | Loss_b: 1.5731e-03
# Step: NaN | Loss: 8.7824e-03 | Loss_d: 9.7946e-03 Loss_e: 8.4562e-03 | Loss_b: 1.5932e-03
# Step: NaN | Loss: 8.7817e-03 | Loss_d: 9.7935e-03 Loss_e: 8.4586e-03 | Loss_b: 1.5947e-03
# Step: NaN | Loss: 8.7839e-03 | Loss_d: 9.7902e-03 Loss_e: 8.5637e-03 | Loss_b: 1.6014e-03
# Step: NaN | Loss: 8.7815e-03 | Loss_d: 9.7927e-03 Loss_e: 8.4680e-03 | Loss_b: 1.5960e-03
# Step: NaN | Loss: 8.7810e-03 | Loss_d: 9.7932e-03 Loss_e: 8.4491e-03 | Loss_b: 1.5940e-03
# Step: NaN | Loss: 8.7845e-03 | Loss_d: 9.7972e-03 Loss_e: 8.4673e-03 | Loss_b: 1.5864e-03
# Step: NaN | Loss: 8.7809e-03 | Loss_d: 9.7935e-03 Loss_e: 8.4435e-03 | Loss_b: 1.5930e-03
# Step: NaN | Loss: 8.7804e-03 | Loss_d: 9.7928e-03 Loss_e: 8.4469e-03 | Loss_b: 1.5920e-03
# Step: NaN | Loss: 8.7826e-03 | Loss_d: 9.7914e-03 Loss_e: 8.5355e-03 | Loss_b: 1.5883e-03
# Step: NaN | Loss: 8.7803e-03 | Loss_d: 9.7925e-03 Loss_e: 8.4534e-03 | Loss_b: 1.5913e-03
# Step: NaN | Loss: 8.7800e-03 | Loss_d: 9.7926e-03 Loss_e: 8.4414e-03 | Loss_b: 1.5929e-03
# Step: NaN | Loss: 8.7809e-03 | Loss_d: 9.7933e-03 Loss_e: 8.4338e-03 | Loss_b: 1.5996e-03
# Step: NaN | Loss: 8.7800e-03 | Loss_d: 9.7927e-03 Loss_e: 8.4340e-03 | Loss_b: 1.5944e-03
# Step: NaN | Loss: 8.7796e-03 | Loss_d: 9.7922e-03 Loss_e: 8.4297e-03 | Loss_b: 1.5978e-03
# Step: NaN | Loss: 8.7804e-03 | Loss_d: 9.7903e-03 Loss_e: 8.4582e-03 | Loss_b: 1.6116e-03
# Step: NaN | Loss: 8.7795e-03 | Loss_d: 9.7916e-03 Loss_e: 8.4303e-03 | Loss_b: 1.6016e-03
# Step: NaN | Loss: 8.7791e-03 | Loss_d: 9.7910e-03 Loss_e: 8.4344e-03 | Loss_b: 1.6021e-03
# Step: NaN | Loss: 8.7789e-03 | Loss_d: 9.7888e-03 Loss_e: 8.4680e-03 | Loss_b: 1.6040e-03
# Step: NaN | Loss: 8.7788e-03 | Loss_d: 9.7894e-03 Loss_e: 8.4543e-03 | Loss_b: 1.6034e-03
# Step: NaN | Loss: 8.7783e-03 | Loss_d: 9.7895e-03 Loss_e: 8.4365e-03 | Loss_b: 1.6061e-03
# Step: NaN | Loss: 8.7799e-03 | Loss_d: 9.7901e-03 Loss_e: 8.4395e-03 | Loss_b: 1.6177e-03
# Step: NaN | Loss: 8.7782e-03 | Loss_d: 9.7895e-03 Loss_e: 8.4272e-03 | Loss_b: 1.6086e-03
# Step: NaN | Loss: 8.7777e-03 | Loss_d: 9.7893e-03 Loss_e: 8.4295e-03 | Loss_b: 1.6040e-03
# Step: NaN | Loss: 8.7798e-03 | Loss_d: 9.7893e-03 Loss_e: 8.5148e-03 | Loss_b: 1.5868e-03
# Step: NaN | Loss: 8.7776e-03 | Loss_d: 9.7892e-03 Loss_e: 8.4355e-03 | Loss_b: 1.6009e-03
# Step: NaN | Loss: 8.7773e-03 | Loss_d: 9.7888e-03 Loss_e: 8.4338e-03 | Loss_b: 1.6022e-03
# Step: NaN | Loss: 8.7810e-03 | Loss_d: 9.7905e-03 Loss_e: 8.4761e-03 | Loss_b: 1.6073e-03
# Step: NaN | Loss: 8.7773e-03 | Loss_d: 9.7888e-03 Loss_e: 8.4339e-03 | Loss_b: 1.6024e-03
# Step: NaN | Loss: 8.7770e-03 | Loss_d: 9.7889e-03 Loss_e: 8.4246e-03 | Loss_b: 1.6032e-03
# Step: NaN | Loss: 8.7770e-03 | Loss_d: 9.7897e-03 Loss_e: 8.3998e-03 | Loss_b: 1.6065e-03
# Step: NaN | Loss: 8.7768e-03 | Loss_d: 9.7893e-03 Loss_e: 8.4083e-03 | Loss_b: 1.6050e-03
# Step: NaN | Loss: 8.7764e-03 | Loss_d: 9.7885e-03 Loss_e: 8.4164e-03 | Loss_b: 1.6034e-03
# Step: NaN | Loss: 8.7770e-03 | Loss_d: 9.7864e-03 Loss_e: 8.4842e-03 | Loss_b: 1.5975e-03
# Step: NaN | Loss: 8.7762e-03 | Loss_d: 9.7877e-03 Loss_e: 8.4331e-03 | Loss_b: 1.6012e-03
# Step: NaN | Loss: 8.7759e-03 | Loss_d: 9.7874e-03 Loss_e: 8.4299e-03 | Loss_b: 1.6018e-03
# Step: NaN | Loss: 8.7774e-03 | Loss_d: 9.7869e-03 Loss_e: 8.4694e-03 | Loss_b: 1.6047e-03
# Step: NaN | Loss: 8.7758e-03 | Loss_d: 9.7872e-03 Loss_e: 8.4308e-03 | Loss_b: 1.6022e-03
# Step: NaN | Loss: 8.7755e-03 | Loss_d: 9.7881e-03 Loss_e: 8.4084e-03 | Loss_b: 1.6006e-03
# Step: NaN | Loss: 8.7762e-03 | Loss_d: 9.7924e-03 Loss_e: 8.3520e-03 | Loss_b: 1.5945e-03
# Step: NaN | Loss: 8.7753e-03 | Loss_d: 9.7891e-03 Loss_e: 8.3875e-03 | Loss_b: 1.5989e-03
# Step: NaN | Loss: 8.7750e-03 | Loss_d: 9.7888e-03 Loss_e: 8.3915e-03 | Loss_b: 1.5963e-03
# Step: NaN | Loss: 8.7752e-03 | Loss_d: 9.7881e-03 Loss_e: 8.4309e-03 | Loss_b: 1.5863e-03
# Step: NaN | Loss: 8.7748e-03 | Loss_d: 9.7884e-03 Loss_e: 8.4033e-03 | Loss_b: 1.5921e-03
# Step: NaN | Loss: 8.7744e-03 | Loss_d: 9.7884e-03 Loss_e: 8.4066e-03 | Loss_b: 1.5858e-03
# Step: NaN | Loss: 8.7772e-03 | Loss_d: 9.7901e-03 Loss_e: 8.4874e-03 | Loss_b: 1.5612e-03
# Step: NaN | Loss: 8.7744e-03 | Loss_d: 9.7885e-03 Loss_e: 8.4098e-03 | Loss_b: 1.5833e-03
# Step: NaN | Loss: 8.7741e-03 | Loss_d: 9.7872e-03 Loss_e: 8.4324e-03 | Loss_b: 1.5806e-03
# Step: NaN | Loss: 8.7771e-03 | Loss_d: 9.7829e-03 Loss_e: 8.6102e-03 | Loss_b: 1.5699e-03
# Step: NaN | Loss: 8.7741e-03 | Loss_d: 9.7869e-03 Loss_e: 8.4395e-03 | Loss_b: 1.5799e-03
# Step: NaN | Loss: 8.7739e-03 | Loss_d: 9.7867e-03 Loss_e: 8.4394e-03 | Loss_b: 1.5806e-03
# Step: NaN | Loss: 8.7742e-03 | Loss_d: 9.7857e-03 Loss_e: 8.4601e-03 | Loss_b: 1.5832e-03
# Step: NaN | Loss: 8.7738e-03 | Loss_d: 9.7863e-03 Loss_e: 8.4423e-03 | Loss_b: 1.5814e-03
# Step: NaN | Loss: 8.7736e-03 | Loss_d: 9.7862e-03 Loss_e: 8.4341e-03 | Loss_b: 1.5835e-03
# Step: NaN | Loss: 8.7734e-03 | Loss_d: 9.7860e-03 Loss_e: 8.4177e-03 | Loss_b: 1.5919e-03
# Step: NaN | Loss: 8.7733e-03 | Loss_d: 9.7861e-03 Loss_e: 8.4205e-03 | Loss_b: 1.5889e-03
# Step: NaN | Loss: 8.7729e-03 | Loss_d: 9.7860e-03 Loss_e: 8.4119e-03 | Loss_b: 1.5900e-03
# Step: NaN | Loss: 8.7733e-03 | Loss_d: 9.7863e-03 Loss_e: 8.4032e-03 | Loss_b: 1.5947e-03
# Step: NaN | Loss: 8.7728e-03 | Loss_d: 9.7860e-03 Loss_e: 8.4037e-03 | Loss_b: 1.5918e-03
# Step: NaN | Loss: 8.7724e-03 | Loss_d: 9.7852e-03 Loss_e: 8.4026e-03 | Loss_b: 1.5960e-03
# Step: NaN | Loss: 8.7746e-03 | Loss_d: 9.7843e-03 Loss_e: 8.4373e-03 | Loss_b: 1.6139e-03
# Step: NaN | Loss: 8.7723e-03 | Loss_d: 9.7848e-03 Loss_e: 8.4035e-03 | Loss_b: 1.5982e-03
# Step: NaN | Loss: 8.7720e-03 | Loss_d: 9.7844e-03 Loss_e: 8.4125e-03 | Loss_b: 1.5950e-03
# Step: NaN | Loss: 8.7742e-03 | Loss_d: 9.7845e-03 Loss_e: 8.4865e-03 | Loss_b: 1.5822e-03
# Step: NaN | Loss: 8.7720e-03 | Loss_d: 9.7842e-03 Loss_e: 8.4169e-03 | Loss_b: 1.5938e-03
# Step: NaN | Loss: 8.7717e-03 | Loss_d: 9.7835e-03 Loss_e: 8.4266e-03 | Loss_b: 1.5928e-03
# Step: NaN | Loss: 8.7720e-03 | Loss_d: 9.7811e-03 Loss_e: 8.4890e-03 | Loss_b: 1.5887e-03
# Step: NaN | Loss: 8.7716e-03 | Loss_d: 9.7825e-03 Loss_e: 8.4464e-03 | Loss_b: 1.5911e-03
# Step: NaN | Loss: 8.7712e-03 | Loss_d: 9.7820e-03 Loss_e: 8.4436e-03 | Loss_b: 1.5935e-03
# Step: NaN | Loss: 8.7710e-03 | Loss_d: 9.7804e-03 Loss_e: 8.4530e-03 | Loss_b: 1.6030e-03
# Step: NaN | Loss: 8.7709e-03 | Loss_d: 9.7810e-03 Loss_e: 8.4453e-03 | Loss_b: 1.5992e-03
# Step: NaN | Loss: 8.7704e-03 | Loss_d: 9.7807e-03 Loss_e: 8.4454e-03 | Loss_b: 1.5956e-03
# Step: NaN | Loss: 8.7728e-03 | Loss_d: 9.7810e-03 Loss_e: 8.5231e-03 | Loss_b: 1.5816e-03
# Step: NaN | Loss: 8.7703e-03 | Loss_d: 9.7806e-03 Loss_e: 8.4500e-03 | Loss_b: 1.5931e-03
# Step: NaN | Loss: 8.7698e-03 | Loss_d: 9.7802e-03 Loss_e: 8.4412e-03 | Loss_b: 1.5962e-03
# Step: NaN | Loss: 8.7715e-03 | Loss_d: 9.7794e-03 Loss_e: 8.4717e-03 | Loss_b: 1.6091e-03
# Step: NaN | Loss: 8.7697e-03 | Loss_d: 9.7799e-03 Loss_e: 8.4390e-03 | Loss_b: 1.5987e-03
# Step: NaN | Loss: 8.7693e-03 | Loss_d: 9.7793e-03 Loss_e: 8.4395e-03 | Loss_b: 1.5994e-03
# Step: NaN | Loss: 8.7710e-03 | Loss_d: 9.7776e-03 Loss_e: 8.5087e-03 | Loss_b: 1.6027e-03
# Step: NaN | Loss: 8.7692e-03 | Loss_d: 9.7789e-03 Loss_e: 8.4439e-03 | Loss_b: 1.5999e-03
# Step: NaN | Loss: 8.7688e-03 | Loss_d: 9.7786e-03 Loss_e: 8.4392e-03 | Loss_b: 1.6021e-03
# Step: NaN | Loss: 8.7695e-03 | Loss_d: 9.7776e-03 Loss_e: 8.4561e-03 | Loss_b: 1.6111e-03
# Step: NaN | Loss: 8.7687e-03 | Loss_d: 9.7782e-03 Loss_e: 8.4382e-03 | Loss_b: 1.6047e-03
# Step: NaN | Loss: 8.7684e-03 | Loss_d: 9.7791e-03 Loss_e: 8.4095e-03 | Loss_b: 1.6059e-03
# Step: NaN | Loss: 8.7726e-03 | Loss_d: 9.7839e-03 Loss_e: 8.4022e-03 | Loss_b: 1.6110e-03
# Step: NaN | Loss: 8.7684e-03 | Loss_d: 9.7792e-03 Loss_e: 8.4072e-03 | Loss_b: 1.6061e-03
# Step: NaN | Loss: 8.7681e-03 | Loss_d: 9.7791e-03 Loss_e: 8.4045e-03 | Loss_b: 1.6060e-03
# Step: NaN | Loss: 8.7679e-03 | Loss_d: 9.7787e-03 Loss_e: 8.4078e-03 | Loss_b: 1.6056e-03
# Step: NaN | Loss: 8.7679e-03 | Loss_d: 9.7788e-03 Loss_e: 8.4044e-03 | Loss_b: 1.6057e-03
# Step: NaN | Loss: 8.7675e-03 | Loss_d: 9.7780e-03 Loss_e: 8.4151e-03 | Loss_b: 1.6037e-03
# Step: NaN | Loss: 8.7690e-03 | Loss_d: 9.7763e-03 Loss_e: 8.4989e-03 | Loss_b: 1.5961e-03
# Step: NaN | Loss: 8.7674e-03 | Loss_d: 9.7775e-03 Loss_e: 8.4262e-03 | Loss_b: 1.6022e-03
# Step: NaN | Loss: 8.7670e-03 | Loss_d: 9.7774e-03 Loss_e: 8.4254e-03 | Loss_b: 1.5989e-03
# Step: NaN | Loss: 8.7675e-03 | Loss_d: 9.7777e-03 Loss_e: 8.4552e-03 | Loss_b: 1.5862e-03
# Step: NaN | Loss: 8.7668e-03 | Loss_d: 9.7774e-03 Loss_e: 8.4300e-03 | Loss_b: 1.5943e-03
# Step: NaN | Loss: 8.7664e-03 | Loss_d: 9.7771e-03 Loss_e: 8.4298e-03 | Loss_b: 1.5924e-03
# Step: NaN | Loss: 8.7664e-03 | Loss_d: 9.7768e-03 Loss_e: 8.4491e-03 | Loss_b: 1.5852e-03
# Step: NaN | Loss: 8.7661e-03 | Loss_d: 9.7768e-03 Loss_e: 8.4355e-03 | Loss_b: 1.5887e-03
# Step: NaN | Loss: 8.7656e-03 | Loss_d: 9.7768e-03 Loss_e: 8.4090e-03 | Loss_b: 1.5967e-03
# Step: NaN | Loss: 8.7713e-03 | Loss_d: 9.7802e-03 Loss_e: 8.4097e-03 | Loss_b: 1.6296e-03
# Step: NaN | Loss: 8.7656e-03 | Loss_d: 9.7768e-03 Loss_e: 8.4076e-03 | Loss_b: 1.5973e-03
# Step: NaN | Loss: 8.7653e-03 | Loss_d: 9.7773e-03 Loss_e: 8.3865e-03 | Loss_b: 1.5993e-03
# Step: NaN | Loss: 8.7668e-03 | Loss_d: 9.7805e-03 Loss_e: 8.3404e-03 | Loss_b: 1.6076e-03
# Step: NaN | Loss: 8.7652e-03 | Loss_d: 9.7777e-03 Loss_e: 8.3740e-03 | Loss_b: 1.6007e-03
# Step: NaN | Loss: 8.7650e-03 | Loss_d: 9.7774e-03 Loss_e: 8.3766e-03 | Loss_b: 1.5999e-03
# Step: NaN | Loss: 8.7648e-03 | Loss_d: 9.7763e-03 Loss_e: 8.3993e-03 | Loss_b: 1.5970e-03
# Step: NaN | Loss: 8.7648e-03 | Loss_d: 9.7767e-03 Loss_e: 8.3882e-03 | Loss_b: 1.5981e-03
# Step: NaN | Loss: 8.7644e-03 | Loss_d: 9.7769e-03 Loss_e: 8.3720e-03 | Loss_b: 1.5997e-03
# Step: NaN | Loss: 8.7663e-03 | Loss_d: 9.7788e-03 Loss_e: 8.3654e-03 | Loss_b: 1.6066e-03
# Step: NaN | Loss: 8.7644e-03 | Loss_d: 9.7771e-03 Loss_e: 8.3657e-03 | Loss_b: 1.6006e-03
# Step: NaN | Loss: 8.7641e-03 | Loss_d: 9.7765e-03 Loss_e: 8.3725e-03 | Loss_b: 1.5994e-03
# Step: NaN | Loss: 8.7641e-03 | Loss_d: 9.7748e-03 Loss_e: 8.4184e-03 | Loss_b: 1.5946e-03
# Step: NaN | Loss: 8.7639e-03 | Loss_d: 9.7756e-03 Loss_e: 8.3909e-03 | Loss_b: 1.5971e-03
# Step: NaN | Loss: 8.7634e-03 | Loss_d: 9.7756e-03 Loss_e: 8.3745e-03 | Loss_b: 1.5998e-03
# Step: NaN | Loss: 8.7648e-03 | Loss_d: 9.7765e-03 Loss_e: 8.3659e-03 | Loss_b: 1.6110e-03
# Step: NaN | Loss: 8.7632e-03 | Loss_d: 9.7756e-03 Loss_e: 8.3643e-03 | Loss_b: 1.6024e-03
# Step: NaN | Loss: 8.7630e-03 | Loss_d: 9.7769e-03 Loss_e: 8.3399e-03 | Loss_b: 1.5989e-03
# Step: NaN | Loss: 8.7630e-03 | Loss_d: 9.7767e-03 Loss_e: 8.3431e-03 | Loss_b: 1.5995e-03
# Step: NaN | Loss: 8.7628e-03 | Loss_d: 9.7764e-03 Loss_e: 8.3467e-03 | Loss_b: 1.5986e-03
# Step: NaN | Loss: 8.7630e-03 | Loss_d: 9.7753e-03 Loss_e: 8.3806e-03 | Loss_b: 1.5950e-03
# Step: NaN | Loss: 8.7627e-03 | Loss_d: 9.7760e-03 Loss_e: 8.3547e-03 | Loss_b: 1.5974e-03
# Step: NaN | Loss: 8.7624e-03 | Loss_d: 9.7757e-03 Loss_e: 8.3527e-03 | Loss_b: 1.5977e-03
# Step: NaN | Loss: 8.7623e-03 | Loss_d: 9.7750e-03 Loss_e: 8.3615e-03 | Loss_b: 1.5992e-03
# Step: NaN | Loss: 8.7622e-03 | Loss_d: 9.7753e-03 Loss_e: 8.3543e-03 | Loss_b: 1.5986e-03
# Step: NaN | Loss: 8.7619e-03 | Loss_d: 9.7754e-03 Loss_e: 8.3439e-03 | Loss_b: 1.5991e-03
# Step: NaN | Loss: 8.7628e-03 | Loss_d: 9.7766e-03 Loss_e: 8.3389e-03 | Loss_b: 1.6013e-03
# Step: NaN | Loss: 8.7618e-03 | Loss_d: 9.7756e-03 Loss_e: 8.3376e-03 | Loss_b: 1.5995e-03
# Step: NaN | Loss: 8.7614e-03 | Loss_d: 9.7748e-03 Loss_e: 8.3438e-03 | Loss_b: 1.6001e-03
# Step: NaN | Loss: 8.7619e-03 | Loss_d: 9.7722e-03 Loss_e: 8.4004e-03 | Loss_b: 1.6025e-03
# Step: NaN | Loss: 8.7612e-03 | Loss_d: 9.7737e-03 Loss_e: 8.3581e-03 | Loss_b: 1.6009e-03
# Step: NaN | Loss: 8.7608e-03 | Loss_d: 9.7730e-03 Loss_e: 8.3574e-03 | Loss_b: 1.6038e-03
# Step: NaN | Loss: 8.7633e-03 | Loss_d: 9.7715e-03 Loss_e: 8.4238e-03 | Loss_b: 1.6153e-03
# Step: NaN | Loss: 8.7608e-03 | Loss_d: 9.7727e-03 Loss_e: 8.3595e-03 | Loss_b: 1.6052e-03
# Step: NaN | Loss: 8.7606e-03 | Loss_d: 9.7728e-03 Loss_e: 8.3552e-03 | Loss_b: 1.6036e-03
# Step: NaN | Loss: 8.7608e-03 | Loss_d: 9.7736e-03 Loss_e: 8.3557e-03 | Loss_b: 1.5975e-03
# Step: NaN | Loss: 8.7604e-03 | Loss_d: 9.7731e-03 Loss_e: 8.3521e-03 | Loss_b: 1.6012e-03
# Step: NaN | Loss: 8.7602e-03 | Loss_d: 9.7728e-03 Loss_e: 8.3531e-03 | Loss_b: 1.6011e-03
# Step: NaN | Loss: 8.7633e-03 | Loss_d: 9.7737e-03 Loss_e: 8.4092e-03 | Loss_b: 1.6008e-03
# Step: NaN | Loss: 8.7602e-03 | Loss_d: 9.7728e-03 Loss_e: 8.3532e-03 | Loss_b: 1.6011e-03
# Step: NaN | Loss: 8.7600e-03 | Loss_d: 9.7727e-03 Loss_e: 8.3509e-03 | Loss_b: 1.6004e-03
# Step: NaN | Loss: 8.7597e-03 | Loss_d: 9.7728e-03 Loss_e: 8.3471e-03 | Loss_b: 1.5976e-03
# Step: NaN | Loss: 8.7597e-03 | Loss_d: 9.7728e-03 Loss_e: 8.3471e-03 | Loss_b: 1.5977e-03
# Step: NaN | Loss: 8.7593e-03 | Loss_d: 9.7724e-03 Loss_e: 8.3368e-03 | Loss_b: 1.6025e-03
# Step: NaN | Loss: 8.7597e-03 | Loss_d: 9.7714e-03 Loss_e: 8.3274e-03 | Loss_b: 1.6219e-03
# Step: NaN | Loss: 8.7591e-03 | Loss_d: 9.7719e-03 Loss_e: 8.3272e-03 | Loss_b: 1.6098e-03
# Step: NaN | Loss: 8.7587e-03 | Loss_d: 9.7724e-03 Loss_e: 8.3019e-03 | Loss_b: 1.6122e-03
# Step: NaN | Loss: 8.7611e-03 | Loss_d: 9.7757e-03 Loss_e: 8.2744e-03 | Loss_b: 1.6218e-03
# Step: NaN | Loss: 8.7586e-03 | Loss_d: 9.7728e-03 Loss_e: 8.2915e-03 | Loss_b: 1.6135e-03
# Step: NaN | Loss: 8.7583e-03 | Loss_d: 9.7728e-03 Loss_e: 8.2791e-03 | Loss_b: 1.6148e-03
# Step: NaN | Loss: 8.7607e-03 | Loss_d: 9.7738e-03 Loss_e: 8.3058e-03 | Loss_b: 1.6204e-03
# Step: NaN | Loss: 8.7583e-03 | Loss_d: 9.7729e-03 Loss_e: 8.2761e-03 | Loss_b: 1.6154e-03
# Step: NaN | Loss: 8.7581e-03 | Loss_d: 9.7719e-03 Loss_e: 8.2830e-03 | Loss_b: 1.6192e-03
# Step: NaN | Loss: 8.7607e-03 | Loss_d: 9.7691e-03 Loss_e: 8.3711e-03 | Loss_b: 1.6349e-03
# Step: NaN | Loss: 8.7580e-03 | Loss_d: 9.7718e-03 Loss_e: 8.2841e-03 | Loss_b: 1.6196e-03
# Step: NaN | Loss: 8.7579e-03 | Loss_d: 9.7717e-03 Loss_e: 8.2804e-03 | Loss_b: 1.6202e-03
# Step: NaN | Loss: 8.7579e-03 | Loss_d: 9.7716e-03 Loss_e: 8.2790e-03 | Loss_b: 1.6226e-03
# Step: NaN | Loss: 8.7577e-03 | Loss_d: 9.7716e-03 Loss_e: 8.2770e-03 | Loss_b: 1.6214e-03
# Step: NaN | Loss: 8.7575e-03 | Loss_d: 9.7712e-03 Loss_e: 8.2855e-03 | Loss_b: 1.6183e-03
# Step: NaN | Loss: 8.7576e-03 | Loss_d: 9.7698e-03 Loss_e: 8.3394e-03 | Loss_b: 1.6060e-03
# Step: NaN | Loss: 8.7573e-03 | Loss_d: 9.7705e-03 Loss_e: 8.3066e-03 | Loss_b: 1.6126e-03
# Step: NaN | Loss: 8.7569e-03 | Loss_d: 9.7694e-03 Loss_e: 8.3186e-03 | Loss_b: 1.6136e-03
# Step: NaN | Loss: 8.7579e-03 | Loss_d: 9.7654e-03 Loss_e: 8.4112e-03 | Loss_b: 1.6180e-03
# Step: NaN | Loss: 8.7568e-03 | Loss_d: 9.7683e-03 Loss_e: 8.3354e-03 | Loss_b: 1.6147e-03
# Step: NaN | Loss: 8.7565e-03 | Loss_d: 9.7685e-03 Loss_e: 8.3184e-03 | Loss_b: 1.6166e-03
# Step: NaN | Loss: 8.7576e-03 | Loss_d: 9.7706e-03 Loss_e: 8.2877e-03 | Loss_b: 1.6245e-03
# Step: NaN | Loss: 8.7564e-03 | Loss_d: 9.7688e-03 Loss_e: 8.3068e-03 | Loss_b: 1.6183e-03
# Step: NaN | Loss: 8.7560e-03 | Loss_d: 9.7690e-03 Loss_e: 8.3012e-03 | Loss_b: 1.6157e-03
# Step: NaN | Loss: 8.7570e-03 | Loss_d: 9.7706e-03 Loss_e: 8.3110e-03 | Loss_b: 1.6057e-03
# Step: NaN | Loss: 8.7559e-03 | Loss_d: 9.7692e-03 Loss_e: 8.2988e-03 | Loss_b: 1.6132e-03
# Step: NaN | Loss: 8.7556e-03 | Loss_d: 9.7691e-03 Loss_e: 8.2911e-03 | Loss_b: 1.6145e-03
# Step: NaN | Loss: 8.7561e-03 | Loss_d: 9.7694e-03 Loss_e: 8.2852e-03 | Loss_b: 1.6202e-03
# Step: NaN | Loss: 8.7555e-03 | Loss_d: 9.7690e-03 Loss_e: 8.2848e-03 | Loss_b: 1.6163e-03
# Step: NaN | Loss: 8.7551e-03 | Loss_d: 9.7695e-03 Loss_e: 8.2708e-03 | Loss_b: 1.6149e-03
# Step: NaN | Loss: 8.7577e-03 | Loss_d: 9.7730e-03 Loss_e: 8.2719e-03 | Loss_b: 1.6093e-03
# Step: NaN | Loss: 8.7551e-03 | Loss_d: 9.7697e-03 Loss_e: 8.2673e-03 | Loss_b: 1.6144e-03
# Step: NaN | Loss: 8.7549e-03 | Loss_d: 9.7696e-03 Loss_e: 8.2662e-03 | Loss_b: 1.6131e-03
# Step: NaN | Loss: 8.7552e-03 | Loss_d: 9.7697e-03 Loss_e: 8.2841e-03 | Loss_b: 1.6078e-03
# Step: NaN | Loss: 8.7547e-03 | Loss_d: 9.7695e-03 Loss_e: 8.2681e-03 | Loss_b: 1.6114e-03
# Step: NaN | Loss: 8.7544e-03 | Loss_d: 9.7693e-03 Loss_e: 8.2749e-03 | Loss_b: 1.6065e-03
# Step: NaN | Loss: 8.7541e-03 | Loss_d: 9.7687e-03 Loss_e: 8.3178e-03 | Loss_b: 1.5871e-03
# Step: NaN | Loss: 8.7541e-03 | Loss_d: 9.7688e-03 Loss_e: 8.3048e-03 | Loss_b: 1.5919e-03
# Step: NaN | Loss: 8.7536e-03 | Loss_d: 9.7691e-03 Loss_e: 8.3068e-03 | Loss_b: 1.5826e-03
# Step: NaN | Loss: 8.7562e-03 | Loss_d: 9.7717e-03 Loss_e: 8.3898e-03 | Loss_b: 1.5461e-03
# Step: NaN | Loss: 8.7535e-03 | Loss_d: 9.7693e-03 Loss_e: 8.3109e-03 | Loss_b: 1.5778e-03
# Step: NaN | Loss: 8.7531e-03 | Loss_d: 9.7686e-03 Loss_e: 8.3309e-03 | Loss_b: 1.5703e-03
# Step: NaN | Loss: 8.7542e-03 | Loss_d: 9.7663e-03 Loss_e: 8.4591e-03 | Loss_b: 1.5407e-03
# Step: NaN | Loss: 8.7530e-03 | Loss_d: 9.7678e-03 Loss_e: 8.3574e-03 | Loss_b: 1.5624e-03
# Step: NaN | Loss: 8.7526e-03 | Loss_d: 9.7687e-03 Loss_e: 8.3368e-03 | Loss_b: 1.5595e-03
# Step: NaN | Loss: 8.7574e-03 | Loss_d: 9.7732e-03 Loss_e: 8.3821e-03 | Loss_b: 1.5482e-03
# Step: NaN | Loss: 8.7526e-03 | Loss_d: 9.7688e-03 Loss_e: 8.3354e-03 | Loss_b: 1.5592e-03
# Step: NaN | Loss: 8.7522e-03 | Loss_d: 9.7690e-03 Loss_e: 8.3169e-03 | Loss_b: 1.5618e-03
# Step: NaN | Loss: 8.7523e-03 | Loss_d: 9.7703e-03 Loss_e: 8.2728e-03 | Loss_b: 1.5724e-03
# Step: NaN | Loss: 8.7519e-03 | Loss_d: 9.7695e-03 Loss_e: 8.2913e-03 | Loss_b: 1.5665e-03
# Step: NaN | Loss: 8.7516e-03 | Loss_d: 9.7695e-03 Loss_e: 8.2782e-03 | Loss_b: 1.5687e-03
# Step: NaN | Loss: 8.7517e-03 | Loss_d: 9.7699e-03 Loss_e: 8.2566e-03 | Loss_b: 1.5776e-03
# Step: NaN | Loss: 8.7513e-03 | Loss_d: 9.7696e-03 Loss_e: 8.2622e-03 | Loss_b: 1.5727e-03
# Step: NaN | Loss: 8.7509e-03 | Loss_d: 9.7696e-03 Loss_e: 8.2552e-03 | Loss_b: 1.5712e-03
# Step: NaN | Loss: 8.7541e-03 | Loss_d: 9.7708e-03 Loss_e: 8.3205e-03 | Loss_b: 1.5650e-03
# Step: NaN | Loss: 8.7509e-03 | Loss_d: 9.7697e-03 Loss_e: 8.2550e-03 | Loss_b: 1.5706e-03
# Step: NaN | Loss: 8.7506e-03 | Loss_d: 9.7693e-03 Loss_e: 8.2514e-03 | Loss_b: 1.5722e-03
# Step: NaN | Loss: 8.7515e-03 | Loss_d: 9.7684e-03 Loss_e: 8.2812e-03 | Loss_b: 1.5785e-03
# Step: NaN | Loss: 8.7505e-03 | Loss_d: 9.7690e-03 Loss_e: 8.2521e-03 | Loss_b: 1.5736e-03
# Step: NaN | Loss: 8.7502e-03 | Loss_d: 9.7689e-03 Loss_e: 8.2469e-03 | Loss_b: 1.5743e-03
# Step: NaN | Loss: 8.7501e-03 | Loss_d: 9.7686e-03 Loss_e: 8.2443e-03 | Loss_b: 1.5774e-03
# Step: NaN | Loss: 8.7499e-03 | Loss_d: 9.7687e-03 Loss_e: 8.2418e-03 | Loss_b: 1.5761e-03
# Step: NaN | Loss: 8.7496e-03 | Loss_d: 9.7683e-03 Loss_e: 8.2501e-03 | Loss_b: 1.5717e-03
# Step: NaN | Loss: 8.7540e-03 | Loss_d: 9.7693e-03 Loss_e: 8.3675e-03 | Loss_b: 1.5549e-03
# Step: NaN | Loss: 8.7496e-03 | Loss_d: 9.7682e-03 Loss_e: 8.2516e-03 | Loss_b: 1.5712e-03
# Step: NaN | Loss: 8.7493e-03 | Loss_d: 9.7680e-03 Loss_e: 8.2451e-03 | Loss_b: 1.5732e-03
# Step: NaN | Loss: 8.7491e-03 | Loss_d: 9.7677e-03 Loss_e: 8.2333e-03 | Loss_b: 1.5813e-03
# Step: NaN | Loss: 8.7490e-03 | Loss_d: 9.7677e-03 Loss_e: 8.2355e-03 | Loss_b: 1.5779e-03
# Step: NaN | Loss: 8.7486e-03 | Loss_d: 9.7681e-03 Loss_e: 8.2127e-03 | Loss_b: 1.5805e-03
# Step: NaN | Loss: 8.7521e-03 | Loss_d: 9.7715e-03 Loss_e: 8.2072e-03 | Loss_b: 1.5915e-03
# Step: NaN | Loss: 8.7486e-03 | Loss_d: 9.7683e-03 Loss_e: 8.2076e-03 | Loss_b: 1.5813e-03
# Step: NaN | Loss: 8.7483e-03 | Loss_d: 9.7678e-03 Loss_e: 8.2106e-03 | Loss_b: 1.5809e-03
# Step: NaN | Loss: 8.7482e-03 | Loss_d: 9.7663e-03 Loss_e: 8.2433e-03 | Loss_b: 1.5791e-03
# Step: NaN | Loss: 8.7480e-03 | Loss_d: 9.7670e-03 Loss_e: 8.2240e-03 | Loss_b: 1.5799e-03
# Step: NaN | Loss: 8.7476e-03 | Loss_d: 9.7665e-03 Loss_e: 8.2148e-03 | Loss_b: 1.5841e-03
# Step: NaN | Loss: 8.7478e-03 | Loss_d: 9.7654e-03 Loss_e: 8.2082e-03 | Loss_b: 1.6011e-03
# Step: NaN | Loss: 8.7474e-03 | Loss_d: 9.7659e-03 Loss_e: 8.2060e-03 | Loss_b: 1.5914e-03
# Step: NaN | Loss: 8.7469e-03 | Loss_d: 9.7662e-03 Loss_e: 8.1843e-03 | Loss_b: 1.5935e-03
# Step: NaN | Loss: 8.7506e-03 | Loss_d: 9.7688e-03 Loss_e: 8.2015e-03 | Loss_b: 1.6023e-03
# Step: NaN | Loss: 8.7469e-03 | Loss_d: 9.7664e-03 Loss_e: 8.1794e-03 | Loss_b: 1.5942e-03
# Step: NaN | Loss: 8.7466e-03 | Loss_d: 9.7654e-03 Loss_e: 8.1832e-03 | Loss_b: 1.5991e-03
# Step: NaN | Loss: 8.7466e-03 | Loss_d: 9.7655e-03 Loss_e: 8.1827e-03 | Loss_b: 1.5989e-03
# Step: NaN | Loss: 8.7464e-03 | Loss_d: 9.7653e-03 Loss_e: 8.1779e-03 | Loss_b: 1.6007e-03
# Step: NaN | Loss: 8.7461e-03 | Loss_d: 9.7646e-03 Loss_e: 8.1696e-03 | Loss_b: 1.6079e-03
# Step: NaN | Loss: 8.7461e-03 | Loss_d: 9.7646e-03 Loss_e: 8.1698e-03 | Loss_b: 1.6068e-03
# Step: NaN | Loss: 8.7456e-03 | Loss_d: 9.7642e-03 Loss_e: 8.1777e-03 | Loss_b: 1.6022e-03
# Step: NaN | Loss: 8.7456e-03 | Loss_d: 9.7630e-03 Loss_e: 8.2369e-03 | Loss_b: 1.5844e-03
# Step: NaN | Loss: 8.7453e-03 | Loss_d: 9.7634e-03 Loss_e: 8.2027e-03 | Loss_b: 1.5930e-03
# Step: NaN | Loss: 8.7446e-03 | Loss_d: 9.7618e-03 Loss_e: 8.2236e-03 | Loss_b: 1.5916e-03
# Step: NaN | Loss: 8.7490e-03 | Loss_d: 9.7564e-03 Loss_e: 8.4434e-03 | Loss_b: 1.5873e-03
# Step: NaN | Loss: 8.7446e-03 | Loss_d: 9.7612e-03 Loss_e: 8.2357e-03 | Loss_b: 1.5911e-03
# Step: NaN | Loss: 8.7440e-03 | Loss_d: 9.7610e-03 Loss_e: 8.2328e-03 | Loss_b: 1.5878e-03
# Step: NaN | Loss: 8.7453e-03 | Loss_d: 9.7608e-03 Loss_e: 8.2930e-03 | Loss_b: 1.5744e-03
# Step: NaN | Loss: 8.7438e-03 | Loss_d: 9.7609e-03 Loss_e: 8.2376e-03 | Loss_b: 1.5842e-03
# Step: NaN | Loss: 8.7432e-03 | Loss_d: 9.7610e-03 Loss_e: 8.2307e-03 | Loss_b: 1.5793e-03
# Step: NaN | Loss: 8.7440e-03 | Loss_d: 9.7629e-03 Loss_e: 8.2481e-03 | Loss_b: 1.5606e-03
# Step: NaN | Loss: 8.7429e-03 | Loss_d: 9.7614e-03 Loss_e: 8.2285e-03 | Loss_b: 1.5726e-03
# Step: NaN | Loss: 8.7423e-03 | Loss_d: 9.7610e-03 Loss_e: 8.2173e-03 | Loss_b: 1.5748e-03
# Step: NaN | Loss: 8.7453e-03 | Loss_d: 9.7626e-03 Loss_e: 8.2380e-03 | Loss_b: 1.5842e-03
# Step: NaN | Loss: 8.7422e-03 | Loss_d: 9.7609e-03 Loss_e: 8.2136e-03 | Loss_b: 1.5763e-03
# Step: NaN | Loss: 8.7418e-03 | Loss_d: 9.7607e-03 Loss_e: 8.2132e-03 | Loss_b: 1.5739e-03
# Step: NaN | Loss: 8.7456e-03 | Loss_d: 9.7619e-03 Loss_e: 8.2980e-03 | Loss_b: 1.5645e-03
# Step: NaN | Loss: 8.7417e-03 | Loss_d: 9.7607e-03 Loss_e: 8.2144e-03 | Loss_b: 1.5733e-03
# Step: NaN | Loss: 8.7414e-03 | Loss_d: 9.7603e-03 Loss_e: 8.2122e-03 | Loss_b: 1.5738e-03
# Step: NaN | Loss: 8.7410e-03 | Loss_d: 9.7592e-03 Loss_e: 8.2200e-03 | Loss_b: 1.5757e-03
# Step: NaN | Loss: 8.7409e-03 | Loss_d: 9.7594e-03 Loss_e: 8.2162e-03 | Loss_b: 1.5752e-03
# Step: NaN | Loss: 8.7406e-03 | Loss_d: 9.7602e-03 Loss_e: 8.1868e-03 | Loss_b: 1.5785e-03
# Step: NaN | Loss: 8.7406e-03 | Loss_d: 9.7601e-03 Loss_e: 8.1884e-03 | Loss_b: 1.5783e-03
# Step: NaN | Loss: 8.7403e-03 | Loss_d: 9.7602e-03 Loss_e: 8.1806e-03 | Loss_b: 1.5778e-03
# Step: NaN | Loss: 8.7398e-03 | Loss_d: 9.7608e-03 Loss_e: 8.1607e-03 | Loss_b: 1.5757e-03
# Step: NaN | Loss: 8.7519e-03 | Loss_d: 9.7673e-03 Loss_e: 8.3358e-03 | Loss_b: 1.5661e-03
# Step: NaN | Loss: 8.7398e-03 | Loss_d: 9.7608e-03 Loss_e: 8.1603e-03 | Loss_b: 1.5757e-03
# Step: NaN | Loss: 8.7393e-03 | Loss_d: 9.7603e-03 Loss_e: 8.1621e-03 | Loss_b: 1.5741e-03
# Step: NaN | Loss: 8.7449e-03 | Loss_d: 9.7593e-03 Loss_e: 8.3255e-03 | Loss_b: 1.5689e-03
# Step: NaN | Loss: 8.7393e-03 | Loss_d: 9.7602e-03 Loss_e: 8.1638e-03 | Loss_b: 1.5739e-03
# Step: NaN | Loss: 8.7389e-03 | Loss_d: 9.7604e-03 Loss_e: 8.1615e-03 | Loss_b: 1.5683e-03
# Step: NaN | Loss: 8.7428e-03 | Loss_d: 9.7623e-03 Loss_e: 8.2599e-03 | Loss_b: 1.5463e-03
# Step: NaN | Loss: 8.7389e-03 | Loss_d: 9.7605e-03 Loss_e: 8.1624e-03 | Loss_b: 1.5671e-03
# Step: NaN | Loss: 8.7385e-03 | Loss_d: 9.7599e-03 Loss_e: 8.1730e-03 | Loss_b: 1.5636e-03
# Step: NaN | Loss: 8.7380e-03 | Loss_d: 9.7577e-03 Loss_e: 8.2306e-03 | Loss_b: 1.5498e-03
# Step: NaN | Loss: 8.7380e-03 | Loss_d: 9.7579e-03 Loss_e: 8.2243e-03 | Loss_b: 1.5510e-03
# Step: NaN | Loss: 8.7374e-03 | Loss_d: 9.7581e-03 Loss_e: 8.2084e-03 | Loss_b: 1.5509e-03
# Step: NaN | Loss: 8.7393e-03 | Loss_d: 9.7596e-03 Loss_e: 8.2239e-03 | Loss_b: 1.5506e-03
# Step: NaN | Loss: 8.7373e-03 | Loss_d: 9.7583e-03 Loss_e: 8.2011e-03 | Loss_b: 1.5508e-03
# Step: NaN | Loss: 8.7368e-03 | Loss_d: 9.7580e-03 Loss_e: 8.2038e-03 | Loss_b: 1.5465e-03
# Step: NaN | Loss: 8.7385e-03 | Loss_d: 9.7574e-03 Loss_e: 8.2901e-03 | Loss_b: 1.5296e-03
# Step: NaN | Loss: 8.7366e-03 | Loss_d: 9.7578e-03 Loss_e: 8.2119e-03 | Loss_b: 1.5429e-03
# Step: NaN | Loss: 8.7361e-03 | Loss_d: 9.7572e-03 Loss_e: 8.2109e-03 | Loss_b: 1.5433e-03
# Step: NaN | Loss: 8.7379e-03 | Loss_d: 9.7558e-03 Loss_e: 8.2764e-03 | Loss_b: 1.5455e-03
# Step: NaN | Loss: 8.7360e-03 | Loss_d: 9.7567e-03 Loss_e: 8.2155e-03 | Loss_b: 1.5437e-03
# Step: NaN | Loss: 8.7354e-03 | Loss_d: 9.7568e-03 Loss_e: 8.1950e-03 | Loss_b: 1.5464e-03
# Step: NaN | Loss: 8.7361e-03 | Loss_d: 9.7585e-03 Loss_e: 8.1547e-03 | Loss_b: 1.5578e-03
# Step: NaN | Loss: 8.7351e-03 | Loss_d: 9.7572e-03 Loss_e: 8.1732e-03 | Loss_b: 1.5502e-03
# Step: NaN | Loss: 8.7345e-03 | Loss_d: 9.7563e-03 Loss_e: 8.1835e-03 | Loss_b: 1.5475e-03
# Step: NaN | Loss: 8.7373e-03 | Loss_d: 9.7546e-03 Loss_e: 8.3019e-03 | Loss_b: 1.5371e-03
# Step: NaN | Loss: 8.7344e-03 | Loss_d: 9.7558e-03 Loss_e: 8.1938e-03 | Loss_b: 1.5458e-03
# Step: NaN | Loss: 8.7341e-03 | Loss_d: 9.7550e-03 Loss_e: 8.1935e-03 | Loss_b: 1.5502e-03
# Step: NaN | Loss: 8.7373e-03 | Loss_d: 9.7543e-03 Loss_e: 8.2461e-03 | Loss_b: 1.5686e-03
# Step: NaN | Loss: 8.7341e-03 | Loss_d: 9.7548e-03 Loss_e: 8.1943e-03 | Loss_b: 1.5514e-03
# Step: NaN | Loss: 8.7338e-03 | Loss_d: 9.7550e-03 Loss_e: 8.1794e-03 | Loss_b: 1.5533e-03
# Step: NaN | Loss: 8.7335e-03 | Loss_d: 9.7561e-03 Loss_e: 8.1356e-03 | Loss_b: 1.5615e-03
# Step: NaN | Loss: 8.7335e-03 | Loss_d: 9.7557e-03 Loss_e: 8.1471e-03 | Loss_b: 1.5588e-03
# Step: NaN | Loss: 8.7330e-03 | Loss_d: 9.7552e-03 Loss_e: 8.1472e-03 | Loss_b: 1.5577e-03
# Step: NaN | Loss: 8.7343e-03 | Loss_d: 9.7544e-03 Loss_e: 8.2027e-03 | Loss_b: 1.5534e-03
# Step: NaN | Loss: 8.7328e-03 | Loss_d: 9.7549e-03 Loss_e: 8.1528e-03 | Loss_b: 1.5566e-03
# Step: NaN | Loss: 8.7324e-03 | Loss_d: 9.7544e-03 Loss_e: 8.1520e-03 | Loss_b: 1.5571e-03
# Step: NaN | Loss: 8.7351e-03 | Loss_d: 9.7534e-03 Loss_e: 8.2306e-03 | Loss_b: 1.5595e-03
# Step: NaN | Loss: 8.7324e-03 | Loss_d: 9.7542e-03 Loss_e: 8.1543e-03 | Loss_b: 1.5574e-03
# Step: NaN | Loss: 8.7319e-03 | Loss_d: 9.7540e-03 Loss_e: 8.1524e-03 | Loss_b: 1.5553e-03
# Step: NaN | Loss: 8.7317e-03 | Loss_d: 9.7535e-03 Loss_e: 8.1720e-03 | Loss_b: 1.5474e-03
# Step: NaN | Loss: 8.7315e-03 | Loss_d: 9.7536e-03 Loss_e: 8.1590e-03 | Loss_b: 1.5505e-03
# Step: NaN | Loss: 8.7312e-03 | Loss_d: 9.7517e-03 Loss_e: 8.1876e-03 | Loss_b: 1.5518e-03
# Step: NaN | Loss: 8.7312e-03 | Loss_d: 9.7522e-03 Loss_e: 8.1771e-03 | Loss_b: 1.5514e-03
# Step: NaN | Loss: 8.7309e-03 | Loss_d: 9.7520e-03 Loss_e: 8.1719e-03 | Loss_b: 1.5530e-03
# Step: NaN | Loss: 8.7305e-03 | Loss_d: 9.7512e-03 Loss_e: 8.1655e-03 | Loss_b: 1.5594e-03
# Step: NaN | Loss: 8.7305e-03 | Loss_d: 9.7513e-03 Loss_e: 8.1650e-03 | Loss_b: 1.5584e-03
# Step: NaN | Loss: 8.7300e-03 | Loss_d: 9.7507e-03 Loss_e: 8.1575e-03 | Loss_b: 1.5619e-03
# Step: NaN | Loss: 8.7305e-03 | Loss_d: 9.7489e-03 Loss_e: 8.1780e-03 | Loss_b: 1.5763e-03
# Step: NaN | Loss: 8.7297e-03 | Loss_d: 9.7500e-03 Loss_e: 8.1557e-03 | Loss_b: 1.5673e-03
# Step: NaN | Loss: 8.7292e-03 | Loss_d: 9.7496e-03 Loss_e: 8.1384e-03 | Loss_b: 1.5738e-03
# Step: NaN | Loss: 8.7319e-03 | Loss_d: 9.7493e-03 Loss_e: 8.1562e-03 | Loss_b: 1.6005e-03
# Step: NaN | Loss: 8.7291e-03 | Loss_d: 9.7494e-03 Loss_e: 8.1327e-03 | Loss_b: 1.5773e-03
# Step: NaN | Loss: 8.7287e-03 | Loss_d: 9.7494e-03 Loss_e: 8.1236e-03 | Loss_b: 1.5771e-03
# Step: NaN | Loss: 8.7315e-03 | Loss_d: 9.7498e-03 Loss_e: 8.1823e-03 | Loss_b: 1.5762e-03
# Step: NaN | Loss: 8.7286e-03 | Loss_d: 9.7494e-03 Loss_e: 8.1225e-03 | Loss_b: 1.5770e-03
# Step: NaN | Loss: 8.7283e-03 | Loss_d: 9.7488e-03 Loss_e: 8.1297e-03 | Loss_b: 1.5746e-03
# Step: NaN | Loss: 8.7279e-03 | Loss_d: 9.7469e-03 Loss_e: 8.1802e-03 | Loss_b: 1.5649e-03
# Step: NaN | Loss: 8.7278e-03 | Loss_d: 9.7475e-03 Loss_e: 8.1591e-03 | Loss_b: 1.5682e-03
# Step: NaN | Loss: 8.7273e-03 | Loss_d: 9.7471e-03 Loss_e: 8.1472e-03 | Loss_b: 1.5714e-03
# Step: NaN | Loss: 8.7338e-03 | Loss_d: 9.7491e-03 Loss_e: 8.2350e-03 | Loss_b: 1.5850e-03
# ...
# Step: NaN | Loss: 8.2171e-03 | Loss_d: 9.2390e-03 Loss_e: 6.6520e-03 | Loss_b: 1.3722e-03
# Step: NaN | Loss: 8.2161e-03 | Loss_d: 9.2396e-03 Loss_e: 6.6130e-03 | Loss_b: 1.3733e-03
# Step: NaN | Loss: 8.2160e-03 | Loss_d: 9.2397e-03 Loss_e: 6.6065e-03 | Loss_b: 1.3744e-03
# Step: NaN | Loss: 8.2165e-03 | Loss_d: 9.2403e-03 Loss_e: 6.5981e-03 | Loss_b: 1.3793e-03
# Step: NaN | Loss: 8.2160e-03 | Loss_d: 9.2398e-03 Loss_e: 6.6033e-03 | Loss_b: 1.3752e-03
# Step: NaN | Loss: 8.2159e-03 | Loss_d: 9.2396e-03 Loss_e: 6.6016e-03 | Loss_b: 1.3770e-03
# Step: NaN | Loss: 8.2166e-03 | Loss_d: 9.2389e-03 Loss_e: 6.6190e-03 | Loss_b: 1.3845e-03
# Step: NaN | Loss: 8.2159e-03 | Loss_d: 9.2395e-03 Loss_e: 6.6017e-03 | Loss_b: 1.3777e-03
# Step: NaN | Loss: 8.2158e-03 | Loss_d: 9.2394e-03 Loss_e: 6.6001e-03 | Loss_b: 1.3785e-03
# Step: NaN | Loss: 8.2157e-03 | Loss_d: 9.2391e-03 Loss_e: 6.5987e-03 | Loss_b: 1.3818e-03
# Step: NaN | Loss: 8.2157e-03 | Loss_d: 9.2392e-03 Loss_e: 6.5984e-03 | Loss_b: 1.3808e-03
# Step: NaN | Loss: 8.2156e-03 | Loss_d: 9.2390e-03 Loss_e: 6.5976e-03 | Loss_b: 1.3817e-03
# Step: NaN | Loss: 8.2157e-03 | Loss_d: 9.2384e-03 Loss_e: 6.6036e-03 | Loss_b: 1.3854e-03
# Step: NaN | Loss: 8.2155e-03 | Loss_d: 9.2387e-03 Loss_e: 6.5985e-03 | Loss_b: 1.3833e-03
# Step: NaN | Loss: 8.2154e-03 | Loss_d: 9.2385e-03 Loss_e: 6.5998e-03 | Loss_b: 1.3836e-03
# Step: NaN | Loss: 8.2159e-03 | Loss_d: 9.2378e-03 Loss_e: 6.6230e-03 | Loss_b: 1.3851e-03
# Step: NaN | Loss: 8.2154e-03 | Loss_d: 9.2383e-03 Loss_e: 6.6022e-03 | Loss_b: 1.3839e-03
# Step: NaN | Loss: 8.2152e-03 | Loss_d: 9.2381e-03 Loss_e: 6.6020e-03 | Loss_b: 1.3844e-03
# Step: NaN | Loss: 8.2158e-03 | Loss_d: 9.2376e-03 Loss_e: 6.6194e-03 | Loss_b: 1.3868e-03
# Step: NaN | Loss: 8.2152e-03 | Loss_d: 9.2379e-03 Loss_e: 6.6030e-03 | Loss_b: 1.3848e-03
# Step: NaN | Loss: 8.2151e-03 | Loss_d: 9.2376e-03 Loss_e: 6.6056e-03 | Loss_b: 1.3849e-03
# Step: NaN | Loss: 8.2156e-03 | Loss_d: 9.2367e-03 Loss_e: 6.6370e-03 | Loss_b: 1.3852e-03
# Step: NaN | Loss: 8.2150e-03 | Loss_d: 9.2374e-03 Loss_e: 6.6089e-03 | Loss_b: 1.3849e-03
# Step: NaN | Loss: 8.2149e-03 | Loss_d: 9.2375e-03 Loss_e: 6.6078e-03 | Loss_b: 1.3832e-03
# Step: NaN | Loss: 8.2150e-03 | Loss_d: 9.2381e-03 Loss_e: 6.6127e-03 | Loss_b: 1.3762e-03
# Step: NaN | Loss: 8.2148e-03 | Loss_d: 9.2377e-03 Loss_e: 6.6080e-03 | Loss_b: 1.3803e-03
# Step: NaN | Loss: 8.2147e-03 | Loss_d: 9.2376e-03 Loss_e: 6.6095e-03 | Loss_b: 1.3786e-03
# Step: NaN | Loss: 8.2147e-03 | Loss_d: 9.2375e-03 Loss_e: 6.6269e-03 | Loss_b: 1.3722e-03
# Step: NaN | Loss: 8.2146e-03 | Loss_d: 9.2375e-03 Loss_e: 6.6152e-03 | Loss_b: 1.3756e-03
# Step: NaN | Loss: 8.2144e-03 | Loss_d: 9.2373e-03 Loss_e: 6.6148e-03 | Loss_b: 1.3766e-03
# Step: NaN | Loss: 8.2162e-03 | Loss_d: 9.2368e-03 Loss_e: 6.6577e-03 | Loss_b: 1.3811e-03
# Step: NaN | Loss: 8.2144e-03 | Loss_d: 9.2372e-03 Loss_e: 6.6151e-03 | Loss_b: 1.3768e-03
# Step: NaN | Loss: 8.2143e-03 | Loss_d: 9.2372e-03 Loss_e: 6.6120e-03 | Loss_b: 1.3768e-03
# Step: NaN | Loss: 8.2143e-03 | Loss_d: 9.2374e-03 Loss_e: 6.6089e-03 | Loss_b: 1.3768e-03
# Step: NaN | Loss: 8.2142e-03 | Loss_d: 9.2373e-03 Loss_e: 6.6085e-03 | Loss_b: 1.3768e-03
# Step: NaN | Loss: 8.2141e-03 | Loss_d: 9.2371e-03 Loss_e: 6.6095e-03 | Loss_b: 1.3766e-03
# Step: NaN | Loss: 8.2146e-03 | Loss_d: 9.2366e-03 Loss_e: 6.6343e-03 | Loss_b: 1.3757e-03
# Step: NaN | Loss: 8.2140e-03 | Loss_d: 9.2370e-03 Loss_e: 6.6115e-03 | Loss_b: 1.3764e-03
# Step: NaN | Loss: 8.2139e-03 | Loss_d: 9.2372e-03 Loss_e: 6.6046e-03 | Loss_b: 1.3760e-03
# Step: NaN | Loss: 8.2158e-03 | Loss_d: 9.2385e-03 Loss_e: 6.6260e-03 | Loss_b: 1.3746e-03
# Step: NaN | Loss: 8.2139e-03 | Loss_d: 9.2372e-03 Loss_e: 6.6046e-03 | Loss_b: 1.3760e-03
# Step: NaN | Loss: 8.2138e-03 | Loss_d: 9.2373e-03 Loss_e: 6.6024e-03 | Loss_b: 1.3759e-03
# Step: NaN | Loss: 8.2138e-03 | Loss_d: 9.2374e-03 Loss_e: 6.5992e-03 | Loss_b: 1.3754e-03
# Step: NaN | Loss: 8.2137e-03 | Loss_d: 9.2373e-03 Loss_e: 6.5993e-03 | Loss_b: 1.3755e-03
# Step: NaN | Loss: 8.2136e-03 | Loss_d: 9.2374e-03 Loss_e: 6.5976e-03 | Loss_b: 1.3747e-03
# Step: NaN | Loss: 8.2139e-03 | Loss_d: 9.2377e-03 Loss_e: 6.6037e-03 | Loss_b: 1.3715e-03
# Step: NaN | Loss: 8.2136e-03 | Loss_d: 9.2374e-03 Loss_e: 6.5972e-03 | Loss_b: 1.3737e-03
# Step: NaN | Loss: 8.2134e-03 | Loss_d: 9.2373e-03 Loss_e: 6.5932e-03 | Loss_b: 1.3751e-03
# Step: NaN | Loss: 8.2135e-03 | Loss_d: 9.2371e-03 Loss_e: 6.5869e-03 | Loss_b: 1.3806e-03
# Step: NaN | Loss: 8.2133e-03 | Loss_d: 9.2372e-03 Loss_e: 6.5883e-03 | Loss_b: 1.3777e-03
# Step: NaN | Loss: 8.2132e-03 | Loss_d: 9.2369e-03 Loss_e: 6.5889e-03 | Loss_b: 1.3782e-03
# Step: NaN | Loss: 8.2143e-03 | Loss_d: 9.2366e-03 Loss_e: 6.6158e-03 | Loss_b: 1.3808e-03
# Step: NaN | Loss: 8.2132e-03 | Loss_d: 9.2368e-03 Loss_e: 6.5899e-03 | Loss_b: 1.3785e-03
# Step: NaN | Loss: 8.2130e-03 | Loss_d: 9.2367e-03 Loss_e: 6.5897e-03 | Loss_b: 1.3783e-03
# Step: NaN | Loss: 8.2139e-03 | Loss_d: 9.2364e-03 Loss_e: 6.6173e-03 | Loss_b: 1.3777e-03
# Step: NaN | Loss: 8.2130e-03 | Loss_d: 9.2367e-03 Loss_e: 6.5905e-03 | Loss_b: 1.3782e-03
# Step: NaN | Loss: 8.2129e-03 | Loss_d: 9.2363e-03 Loss_e: 6.5946e-03 | Loss_b: 1.3785e-03
# Step: NaN | Loss: 8.2130e-03 | Loss_d: 9.2351e-03 Loss_e: 6.6180e-03 | Loss_b: 1.3797e-03
# Step: NaN | Loss: 8.2129e-03 | Loss_d: 9.2357e-03 Loss_e: 6.6041e-03 | Loss_b: 1.3790e-03
# Step: NaN | Loss: 8.2127e-03 | Loss_d: 9.2356e-03 Loss_e: 6.6027e-03 | Loss_b: 1.3784e-03
# Step: NaN | Loss: 8.2127e-03 | Loss_d: 9.2356e-03 Loss_e: 6.6102e-03 | Loss_b: 1.3761e-03
# Step: NaN | Loss: 8.2126e-03 | Loss_d: 9.2356e-03 Loss_e: 6.6036e-03 | Loss_b: 1.3773e-03
# Step: NaN | Loss: 8.2124e-03 | Loss_d: 9.2360e-03 Loss_e: 6.5980e-03 | Loss_b: 1.3741e-03
# Step: NaN | Loss: 8.2137e-03 | Loss_d: 9.2381e-03 Loss_e: 6.6128e-03 | Loss_b: 1.3613e-03
# Step: NaN | Loss: 8.2124e-03 | Loss_d: 9.2361e-03 Loss_e: 6.5968e-03 | Loss_b: 1.3728e-03
# Step: NaN | Loss: 8.2123e-03 | Loss_d: 9.2361e-03 Loss_e: 6.5963e-03 | Loss_b: 1.3715e-03
# Step: NaN | Loss: 8.2124e-03 | Loss_d: 9.2363e-03 Loss_e: 6.6074e-03 | Loss_b: 1.3663e-03
# Step: NaN | Loss: 8.2122e-03 | Loss_d: 9.2362e-03 Loss_e: 6.5978e-03 | Loss_b: 1.3696e-03
# Step: NaN | Loss: 8.2120e-03 | Loss_d: 9.2360e-03 Loss_e: 6.6039e-03 | Loss_b: 1.3659e-03
# Step: NaN | Loss: 8.2127e-03 | Loss_d: 9.2357e-03 Loss_e: 6.6557e-03 | Loss_b: 1.3516e-03
# Step: NaN | Loss: 8.2120e-03 | Loss_d: 9.2359e-03 Loss_e: 6.6102e-03 | Loss_b: 1.3632e-03
# Step: NaN | Loss: 8.2118e-03 | Loss_d: 9.2355e-03 Loss_e: 6.6214e-03 | Loss_b: 1.3605e-03
# Step: NaN | Loss: 8.2128e-03 | Loss_d: 9.2338e-03 Loss_e: 6.6969e-03 | Loss_b: 1.3502e-03
# Step: NaN | Loss: 8.2118e-03 | Loss_d: 9.2353e-03 Loss_e: 6.6269e-03 | Loss_b: 1.3594e-03
# Step: NaN | Loss: 8.2117e-03 | Loss_d: 9.2352e-03 Loss_e: 6.6291e-03 | Loss_b: 1.3576e-03
# Step: NaN | Loss: 8.2123e-03 | Loss_d: 9.2350e-03 Loss_e: 6.6612e-03 | Loss_b: 1.3508e-03
# Step: NaN | Loss: 8.2117e-03 | Loss_d: 9.2352e-03 Loss_e: 6.6319e-03 | Loss_b: 1.3564e-03
# Step: NaN | Loss: 8.2116e-03 | Loss_d: 9.2352e-03 Loss_e: 6.6297e-03 | Loss_b: 1.3566e-03
# Step: NaN | Loss: 8.2114e-03 | Loss_d: 9.2352e-03 Loss_e: 6.6244e-03 | Loss_b: 1.3575e-03
# Step: NaN | Loss: 8.2150e-03 | Loss_d: 9.2359e-03 Loss_e: 6.6843e-03 | Loss_b: 1.3621e-03
# Step: NaN | Loss: 8.2114e-03 | Loss_d: 9.2352e-03 Loss_e: 6.6243e-03 | Loss_b: 1.3575e-03
# Step: NaN | Loss: 8.2113e-03 | Loss_d: 9.2352e-03 Loss_e: 6.6251e-03 | Loss_b: 1.3549e-03
# Step: NaN | Loss: 8.2117e-03 | Loss_d: 9.2355e-03 Loss_e: 6.6492e-03 | Loss_b: 1.3447e-03
# Step: NaN | Loss: 8.2112e-03 | Loss_d: 9.2352e-03 Loss_e: 6.6281e-03 | Loss_b: 1.3523e-03
# Step: NaN | Loss: 8.2110e-03 | Loss_d: 9.2354e-03 Loss_e: 6.6182e-03 | Loss_b: 1.3531e-03
# Step: NaN | Loss: 8.2123e-03 | Loss_d: 9.2368e-03 Loss_e: 6.6151e-03 | Loss_b: 1.3565e-03
# Step: NaN | Loss: 8.2110e-03 | Loss_d: 9.2355e-03 Loss_e: 6.6156e-03 | Loss_b: 1.3534e-03
# Step: NaN | Loss: 8.2109e-03 | Loss_d: 9.2357e-03 Loss_e: 6.6051e-03 | Loss_b: 1.3556e-03
# Step: NaN | Loss: 8.2110e-03 | Loss_d: 9.2364e-03 Loss_e: 6.5755e-03 | Loss_b: 1.3644e-03
# Step: NaN | Loss: 8.2108e-03 | Loss_d: 9.2359e-03 Loss_e: 6.5900e-03 | Loss_b: 1.3593e-03
# Step: NaN | Loss: 8.2106e-03 | Loss_d: 9.2364e-03 Loss_e: 6.5708e-03 | Loss_b: 1.3623e-03
# Step: NaN | Loss: 8.2122e-03 | Loss_d: 9.2384e-03 Loss_e: 6.5432e-03 | Loss_b: 1.3743e-03
# Step: NaN | Loss: 8.2106e-03 | Loss_d: 9.2365e-03 Loss_e: 6.5659e-03 | Loss_b: 1.3632e-03
# Step: NaN | Loss: 8.2104e-03 | Loss_d: 9.2363e-03 Loss_e: 6.5635e-03 | Loss_b: 1.3647e-03
# Step: NaN | Loss: 8.2103e-03 | Loss_d: 9.2357e-03 Loss_e: 6.5601e-03 | Loss_b: 1.3706e-03
# Step: NaN | Loss: 8.2102e-03 | Loss_d: 9.2358e-03 Loss_e: 6.5600e-03 | Loss_b: 1.3696e-03
# Step: NaN | Loss: 8.2100e-03 | Loss_d: 9.2352e-03 Loss_e: 6.5573e-03 | Loss_b: 1.3741e-03
# Step: NaN | Loss: 8.2114e-03 | Loss_d: 9.2333e-03 Loss_e: 6.5915e-03 | Loss_b: 1.3924e-03
# Step: NaN | Loss: 8.2100e-03 | Loss_d: 9.2350e-03 Loss_e: 6.5576e-03 | Loss_b: 1.3761e-03
# Step: NaN | Loss: 8.2098e-03 | Loss_d: 9.2348e-03 Loss_e: 6.5517e-03 | Loss_b: 1.3785e-03
# Step: NaN | Loss: 8.2104e-03 | Loss_d: 9.2344e-03 Loss_e: 6.5533e-03 | Loss_b: 1.3883e-03
# Step: NaN | Loss: 8.2098e-03 | Loss_d: 9.2347e-03 Loss_e: 6.5486e-03 | Loss_b: 1.3806e-03
# Step: NaN | Loss: 8.2096e-03 | Loss_d: 9.2346e-03 Loss_e: 6.5388e-03 | Loss_b: 1.3840e-03
# Step: NaN | Loss: 8.2099e-03 | Loss_d: 9.2345e-03 Loss_e: 6.5215e-03 | Loss_b: 1.3976e-03
# Step: NaN | Loss: 8.2095e-03 | Loss_d: 9.2345e-03 Loss_e: 6.5292e-03 | Loss_b: 1.3884e-03
# Step: NaN | Loss: 8.2093e-03 | Loss_d: 9.2346e-03 Loss_e: 6.5207e-03 | Loss_b: 1.3898e-03
# Step: NaN | Loss: 8.2108e-03 | Loss_d: 9.2352e-03 Loss_e: 6.5322e-03 | Loss_b: 1.3954e-03
# Step: NaN | Loss: 8.2093e-03 | Loss_d: 9.2347e-03 Loss_e: 6.5192e-03 | Loss_b: 1.3902e-03
# Step: NaN | Loss: 8.2092e-03 | Loss_d: 9.2344e-03 Loss_e: 6.5216e-03 | Loss_b: 1.3901e-03
# Step: NaN | Loss: 8.2102e-03 | Loss_d: 9.2335e-03 Loss_e: 6.5640e-03 | Loss_b: 1.3898e-03
# Step: NaN | Loss: 8.2092e-03 | Loss_d: 9.2343e-03 Loss_e: 6.5234e-03 | Loss_b: 1.3901e-03
# Step: NaN | Loss: 8.2091e-03 | Loss_d: 9.2343e-03 Loss_e: 6.5233e-03 | Loss_b: 1.3892e-03
# Step: NaN | Loss: 8.2090e-03 | Loss_d: 9.2343e-03 Loss_e: 6.5278e-03 | Loss_b: 1.3857e-03
# Step: NaN | Loss: 8.2090e-03 | Loss_d: 9.2343e-03 Loss_e: 6.5265e-03 | Loss_b: 1.3863e-03
# Step: NaN | Loss: 8.2088e-03 | Loss_d: 9.2342e-03 Loss_e: 6.5254e-03 | Loss_b: 1.3853e-03
# Step: NaN | Loss: 8.2090e-03 | Loss_d: 9.2341e-03 Loss_e: 6.5404e-03 | Loss_b: 1.3815e-03
# Step: NaN | Loss: 8.2087e-03 | Loss_d: 9.2341e-03 Loss_e: 6.5271e-03 | Loss_b: 1.3840e-03
# Step: NaN | Loss: 8.2085e-03 | Loss_d: 9.2336e-03 Loss_e: 6.5361e-03 | Loss_b: 1.3834e-03
# Step: NaN | Loss: 8.2094e-03 | Loss_d: 9.2315e-03 Loss_e: 6.6041e-03 | Loss_b: 1.3810e-03
# Step: NaN | Loss: 8.2085e-03 | Loss_d: 9.2332e-03 Loss_e: 6.5431e-03 | Loss_b: 1.3830e-03
# Step: NaN | Loss: 8.2083e-03 | Loss_d: 9.2330e-03 Loss_e: 6.5471e-03 | Loss_b: 1.3810e-03
# Step: NaN | Loss: 8.2085e-03 | Loss_d: 9.2323e-03 Loss_e: 6.5805e-03 | Loss_b: 1.3733e-03
# Step: NaN | Loss: 8.2082e-03 | Loss_d: 9.2327e-03 Loss_e: 6.5559e-03 | Loss_b: 1.3783e-03
# Step: NaN | Loss: 8.2081e-03 | Loss_d: 9.2324e-03 Loss_e: 6.5687e-03 | Loss_b: 1.3734e-03
# Step: NaN | Loss: 8.2100e-03 | Loss_d: 9.2317e-03 Loss_e: 6.6660e-03 | Loss_b: 1.3542e-03
# Step: NaN | Loss: 8.2081e-03 | Loss_d: 9.2323e-03 Loss_e: 6.5719e-03 | Loss_b: 1.3724e-03
# Step: NaN | Loss: 8.2079e-03 | Loss_d: 9.2324e-03 Loss_e: 6.5725e-03 | Loss_b: 1.3699e-03
# Step: NaN | Loss: 8.2080e-03 | Loss_d: 9.2329e-03 Loss_e: 6.5837e-03 | Loss_b: 1.3597e-03
# Step: NaN | Loss: 8.2079e-03 | Loss_d: 9.2326e-03 Loss_e: 6.5759e-03 | Loss_b: 1.3652e-03
# Step: NaN | Loss: 8.2077e-03 | Loss_d: 9.2325e-03 Loss_e: 6.5762e-03 | Loss_b: 1.3646e-03
# Step: NaN | Loss: 8.2082e-03 | Loss_d: 9.2325e-03 Loss_e: 6.5922e-03 | Loss_b: 1.3620e-03
# Step: NaN | Loss: 8.2077e-03 | Loss_d: 9.2324e-03 Loss_e: 6.5776e-03 | Loss_b: 1.3640e-03
# Step: NaN | Loss: 8.2075e-03 | Loss_d: 9.2323e-03 Loss_e: 6.5765e-03 | Loss_b: 1.3635e-03
# Step: NaN | Loss: 8.2074e-03 | Loss_d: 9.2323e-03 Loss_e: 6.5798e-03 | Loss_b: 1.3616e-03
# Step: NaN | Loss: 8.2074e-03 | Loss_d: 9.2323e-03 Loss_e: 6.5772e-03 | Loss_b: 1.3623e-03
# Step: NaN | Loss: 8.2072e-03 | Loss_d: 9.2320e-03 Loss_e: 6.5797e-03 | Loss_b: 1.3613e-03
# Step: NaN | Loss: 8.2087e-03 | Loss_d: 9.2314e-03 Loss_e: 6.6365e-03 | Loss_b: 1.3574e-03
# Step: NaN | Loss: 8.2072e-03 | Loss_d: 9.2319e-03 Loss_e: 6.5818e-03 | Loss_b: 1.3609e-03
# Step: NaN | Loss: 8.2070e-03 | Loss_d: 9.2315e-03 Loss_e: 6.5808e-03 | Loss_b: 1.3639e-03
# Step: NaN | Loss: 8.2078e-03 | Loss_d: 9.2299e-03 Loss_e: 6.6059e-03 | Loss_b: 1.3760e-03
# Step: NaN | Loss: 8.2070e-03 | Loss_d: 9.2311e-03 Loss_e: 6.5818e-03 | Loss_b: 1.3660e-03
# Step: NaN | Loss: 8.2068e-03 | Loss_d: 9.2312e-03 Loss_e: 6.5692e-03 | Loss_b: 1.3699e-03
# Step: NaN | Loss: 8.2084e-03 | Loss_d: 9.2318e-03 Loss_e: 6.5627e-03 | Loss_b: 1.3857e-03
# Step: NaN | Loss: 8.2068e-03 | Loss_d: 9.2313e-03 Loss_e: 6.5681e-03 | Loss_b: 1.3704e-03
# Step: NaN | Loss: 8.2067e-03 | Loss_d: 9.2312e-03 Loss_e: 6.5602e-03 | Loss_b: 1.3730e-03
# Step: NaN | Loss: 8.2066e-03 | Loss_d: 9.2313e-03 Loss_e: 6.5353e-03 | Loss_b: 1.3836e-03
# Step: NaN | Loss: 8.2066e-03 | Loss_d: 9.2312e-03 Loss_e: 6.5398e-03 | Loss_b: 1.3813e-03
# Step: NaN | Loss: 8.2064e-03 | Loss_d: 9.2312e-03 Loss_e: 6.5330e-03 | Loss_b: 1.3832e-03
# Step: NaN | Loss: 8.2064e-03 | Loss_d: 9.2311e-03 Loss_e: 6.5184e-03 | Loss_b: 1.3911e-03
# Step: NaN | Loss: 8.2063e-03 | Loss_d: 9.2311e-03 Loss_e: 6.5228e-03 | Loss_b: 1.3873e-03
# Step: NaN | Loss: 8.2061e-03 | Loss_d: 9.2315e-03 Loss_e: 6.5071e-03 | Loss_b: 1.3898e-03
# Step: NaN | Loss: 8.2076e-03 | Loss_d: 9.2330e-03 Loss_e: 6.4917e-03 | Loss_b: 1.3999e-03
# Step: NaN | Loss: 8.2060e-03 | Loss_d: 9.2316e-03 Loss_e: 6.5025e-03 | Loss_b: 1.3907e-03
# Step: NaN | Loss: 8.2059e-03 | Loss_d: 9.2315e-03 Loss_e: 6.4943e-03 | Loss_b: 1.3933e-03
# Step: NaN | Loss: 8.2062e-03 | Loss_d: 9.2313e-03 Loss_e: 6.4854e-03 | Loss_b: 1.4041e-03
# Step: NaN | Loss: 8.2058e-03 | Loss_d: 9.2314e-03 Loss_e: 6.4878e-03 | Loss_b: 1.3965e-03
# Step: NaN | Loss: 8.2056e-03 | Loss_d: 9.2313e-03 Loss_e: 6.4786e-03 | Loss_b: 1.4007e-03
# Step: NaN | Loss: 8.2074e-03 | Loss_d: 9.2314e-03 Loss_e: 6.4827e-03 | Loss_b: 1.4178e-03
# Step: NaN | Loss: 8.2056e-03 | Loss_d: 9.2313e-03 Loss_e: 6.4775e-03 | Loss_b: 1.4013e-03
# Step: NaN | Loss: 8.2055e-03 | Loss_d: 9.2310e-03 Loss_e: 6.4770e-03 | Loss_b: 1.4030e-03
# Step: NaN | Loss: 8.2055e-03 | Loss_d: 9.2299e-03 Loss_e: 6.4842e-03 | Loss_b: 1.4098e-03
# Step: NaN | Loss: 8.2054e-03 | Loss_d: 9.2303e-03 Loss_e: 6.4793e-03 | Loss_b: 1.4068e-03
# Step: NaN | Loss: 8.2052e-03 | Loss_d: 9.2301e-03 Loss_e: 6.4823e-03 | Loss_b: 1.4045e-03
# Step: NaN | Loss: 8.2054e-03 | Loss_d: 9.2299e-03 Loss_e: 6.5098e-03 | Loss_b: 1.3955e-03
# Step: NaN | Loss: 8.2050e-03 | Loss_d: 9.2300e-03 Loss_e: 6.4896e-03 | Loss_b: 1.4011e-03
# Step: NaN | Loss: 8.2048e-03 | Loss_d: 9.2298e-03 Loss_e: 6.4909e-03 | Loss_b: 1.3997e-03
# Step: NaN | Loss: 8.2056e-03 | Loss_d: 9.2295e-03 Loss_e: 6.5257e-03 | Loss_b: 1.3941e-03
# Step: NaN | Loss: 8.2047e-03 | Loss_d: 9.2296e-03 Loss_e: 6.4944e-03 | Loss_b: 1.3985e-03
# Step: NaN | Loss: 8.2045e-03 | Loss_d: 9.2297e-03 Loss_e: 6.4899e-03 | Loss_b: 1.3977e-03
# Step: NaN | Loss: 8.2055e-03 | Loss_d: 9.2303e-03 Loss_e: 6.5089e-03 | Loss_b: 1.3945e-03
# Step: NaN | Loss: 8.2045e-03 | Loss_d: 9.2297e-03 Loss_e: 6.4890e-03 | Loss_b: 1.3972e-03
# Step: NaN | Loss: 8.2043e-03 | Loss_d: 9.2300e-03 Loss_e: 6.4857e-03 | Loss_b: 1.3941e-03
# Step: NaN | Loss: 8.2048e-03 | Loss_d: 9.2313e-03 Loss_e: 6.4954e-03 | Loss_b: 1.3817e-03
# Step: NaN | Loss: 8.2043e-03 | Loss_d: 9.2303e-03 Loss_e: 6.4848e-03 | Loss_b: 1.3913e-03
# Step: NaN | Loss: 8.2042e-03 | Loss_d: 9.2301e-03 Loss_e: 6.4922e-03 | Loss_b: 1.3880e-03
# Step: NaN | Loss: 8.2058e-03 | Loss_d: 9.2297e-03 Loss_e: 6.5657e-03 | Loss_b: 1.3751e-03
# Step: NaN | Loss: 8.2042e-03 | Loss_d: 9.2301e-03 Loss_e: 6.4930e-03 | Loss_b: 1.3877e-03
#  Total iterations: 9915

# %% [markdown]
# # Prediction
#
# Compute the solution variables and equation residue at high-resolution grids

# %%
# Function of solution and equation residues based on trained networks
f_u = lambda x: pred_u(trained_params2, x)
f_gu = lambda x: vectgrad(f_u, x)[0][:, 0:6]

# group all the function
func_all = (f_u, f_gu, ssa_iso)

# calculate the solution and equation residue at given grids for visualization
results = predict_pinn(func_all, data_all)

# %% [markdown]
# # Plotting the results:
#
# Compare the synthetic data for either velocity or thickness with the corresponding network approximation

# %%
results.keys()
# Out:
# dict_keys(['x', 'y', 'u_g', 'v_g', 'x_h', 'y_h', 'h_g', 'u', 'v', 'h', 'h2', 'u_x', 'u_y', 'v_x', 'v_y', 'h_x', 'h_y', 'str', 'mu', 'e11', 'e12', 'e13', 'e21', 'e22', 'e23', 'e1', 'e2', 'scale'])

# %%
u_g = results['u_g']
u = results['u']

xd = np.nan_to_num(xd, nan=0.0, posinf=0.0, neginf=0.0) # filter out nans/inf values
yd = np.nan_to_num(yd, nan=0.0, posinf=0.0, neginf=0.0)
# Get the shape of the grid
grid_shape = xd.shape  # or yd.shape, should be the same

# Reshape velocity data for plotting
u_g_reshaped = u_g.reshape(grid_shape)
u_reshaped = u.reshape(grid_shape)

fig = plt.figure(figsize = [10, 10], dpi = 70)

ax = plt.subplot(2, 1, 1)
h = ax.imshow(u_g_reshaped, interpolation='nearest', cmap='rainbow',
              extent=[xd.min(), xd.max(), yd.min(), yd.max()],
              origin='lower', aspect='auto', vmin=0, vmax=4e-5)
divider = make_axes_locatable(ax)
cax = divider.append_axes("right", size="4%", pad=0.05)
fig.colorbar(h, cax=cax)

ax.set_xlabel('$x$', fontsize=15)
ax.set_ylabel('$y$', fontsize=15, rotation=0)
ax.set_title('Observed $u_g(x,y)$ (m/s)', fontsize=15)

ax2 = plt.subplot(2, 1, 2)
h2 = ax2.imshow(u_reshaped, interpolation='nearest', cmap='rainbow',
                extent=[xd.min(), xd.max(), yd.min(), yd.max()],
                origin='lower', aspect='auto', vmin=0, vmax=4e-5)
divider = make_axes_locatable(ax2)
cax = divider.append_axes("right", size="4%", pad=0.05)
fig.colorbar(h2, cax=cax)

ax2.set_xlabel('$x$', fontsize=15)
ax2.set_ylabel('$y$', fontsize=15, rotation=0)
ax2.set_title('PINN Inferred $u(x,y)$ (m/s)', fontsize=15)
fig.savefig(f"{output_dir}/u_comp.png", dpi=300, bbox_inches='tight')

# %%
v_g = results['v_g']
v = results['v']

xd = np.nan_to_num(xd, nan=0.0, posinf=0.0, neginf=0.0) # filter out nans/inf values
yd = np.nan_to_num(yd, nan=0.0, posinf=0.0, neginf=0.0)
# Get the shape of the grid
grid_shape = xd.shape  # or yd.shape, should be the same

# Reshape velocity data for plotting
v_g_reshaped = v_g.reshape(grid_shape)
v_reshaped = v.reshape(grid_shape)

fig = plt.figure(figsize = [10, 10], dpi = 70)

ax = plt.subplot(2, 1, 1)
h = ax.imshow(v_g_reshaped, interpolation='nearest', cmap='rainbow',
              extent=[xd.min(), xd.max(), yd.min(), yd.max()],
              origin='lower', aspect='auto', vmin=-2.5e-5, vmax=0.5e-5)
divider = make_axes_locatable(ax)
cax = divider.append_axes("right", size="4%", pad=0.05)
fig.colorbar(h, cax=cax)

ax.set_xlabel('$x$', fontsize=15)
ax.set_ylabel('$y$', fontsize=15, rotation=0)
ax.set_title('Observed $v_g(x,y)$ (m/s)', fontsize=15)

ax2 = plt.subplot(2, 1, 2)
h2 = ax2.imshow(v_reshaped, interpolation='nearest', cmap='rainbow',
                extent=[xd.min(), xd.max(), yd.min(), yd.max()],
                origin='lower', aspect='auto', vmin=-2.5e-5, vmax=0.5e-5)
divider = make_axes_locatable(ax2)
cax = divider.append_axes("right", size="4%", pad=0.05)
fig.colorbar(h2, cax=cax)

ax2.set_xlabel('$x$', fontsize=15)
ax2.set_ylabel('$y$', fontsize=15, rotation=0)
ax2.set_title('PINN Inferred $v(x,y)$ (m/s)', fontsize=15)
fig.savefig(f"{output_dir}/v_comp.png", dpi=300, bbox_inches='tight')

# %%
# calculate residual means: |e1|/|e11|, |e1|/|e12| etc and |e2|/|e21|
print("Mean |e1|/|e11|:", np.nanmean(np.abs(results['e1'])/np.abs(results['e11'])))
print("Mean |e1|/|e12|:", np.nanmean(np.abs(results['e1'])/np.abs(results['e12'])))
print("Mean |e1|/|e13|:", np.nanmean(np.abs(results['e1'])/np.abs(results['e13'])))
print("Mean |e2|/|e21|:", np.nanmean(np.abs(results['e2'])/np.abs(results['e21'])))
print("Mean |e2|/|e22|:", np.nanmean(np.abs(results['e2'])/np.abs(results['e22'])))
print("Mean |e2|/|e23|:", np.nanmean(np.abs(results['e2'])/np.abs(results['e23'])))
# Out:
# Mean |e1|/|e11|: 0.63852024
# Mean |e1|/|e12|: 0.76256514
# Mean |e1|/|e13|: 0.54608446
# Mean |e2|/|e21|: 0.56421024
# Mean |e2|/|e22|: 2.121705
# Mean |e2|/|e23|: 0.45684588

# %%
# plot residuals all together!

# Define keys and layout
residual_keys = ['e1', 'e11', 'e12', 'e13', 'e2', 'e21', 'e22', 'e23']
titles = [r'$e_1$', r'$e_{11}$', r'$e_{12}$', r'$e_{13}$',
          r'$e_2$', r'$e_{21}$', r'$e_{22}$', r'$e_{23}$']

# Prepare shared color scale
vmin, vmax = -1000, 1000  # consistent fixed scale for all residuals

# Create figure and subplots
fig, axs = plt.subplots(2, 4, figsize=(18, 8), dpi=100)
axs = axs.flatten()

# Loop through keys and plot each residual
for i, (key, title) in enumerate(zip(residual_keys, titles)):
    ax = axs[i]
    try:
        reshaped = results[key].reshape(grid_shape)
        im = ax.imshow(reshaped, interpolation='nearest', cmap='RdBu_r',
                       extent=[xd.min(), xd.max(), yd.min(), yd.max()],
                       origin='lower', aspect='auto',
                       vmin=vmin, vmax=vmax)
        ax.set_title(title, fontsize=14)
        ax.set_xlabel('x')
        ax.set_ylabel('y')
    except Exception as e:
        ax.set_title(f"{key} (failed)")
        print(f"Failed to plot {key}: {e}")

# Shared colorbar on the right
# Create a new axis beside the last subplot
divider = make_axes_locatable(axs[-1])
cax = divider.append_axes("right", size="5%", pad=0.1)
fig.colorbar(im, cax=cax)

# Tight layout and save
fig.suptitle("Residual Fields", fontsize=18)
plt.tight_layout(rect=[0, 0, 0.95, 0.95])  # Leave space for colorbar and title
fig.savefig(f"{output_dir}/all_residuals_grid.png", dpi=300)
plt.show()
plt.close(fig)

# %% [markdown]
# Showing the inferred viscosity via PINNs for the ice shelf

# %%
# load the PINN inference of viscosity
mu = results['mu']
mu_reshaped = mu.reshape(grid_shape)

fig = plt.figure(figsize = [10, 5], dpi = 70)

ax = plt.subplot(1,1,1)
h = ax.imshow(mu_reshaped, interpolation='nearest', cmap='rainbow',
              extent=[0., 50000., 0,  80000.],
              origin='lower', aspect='auto')
divider = make_axes_locatable(ax)
cax = divider.append_axes("right", size="4%", pad=0.05)
fig.colorbar(h, cax=cax)

ax.set_xlabel('$x$', fontsize = 15)
ax.set_ylabel('$y\ $', fontsize = 15, rotation = 0)
ax.set_title('Inferred viscosity $\mu(x,y)$', fontsize = 15)
#fig.savefig(f"{output_dir}/inferred_visc_2.png", dpi=300, bbox_inches='tight')
# Out:
# Text(0.5, 1.0, 'Inferred viscosity $\\mu(x,y)$')

# %%
# log-scaled colorbar for vicosity plot
# avoid log(0): set a small floor value
mu_reshaped = np.where(mu_reshaped <= 0, 1e-3, mu_reshaped)

fig = plt.figure(figsize=[10, 5], dpi=70)

ax = plt.subplot(1, 1, 1)

# Use LogNorm for color scaling
h = ax.imshow(mu_reshaped, interpolation='nearest', cmap='plasma',
              norm=LogNorm(vmin=1e13, vmax = 4e15), # , vmin=4e13, vmax = 4e15
              extent=[0., 50000., 0, 80000.],
              origin='lower', aspect='auto')

divider = make_axes_locatable(ax)
cax = divider.append_axes("right", size="4%", pad=0.05)
fig.colorbar(h, cax=cax)

ax.set_xlabel('$x$', fontsize=15)
ax.set_ylabel('$y$', fontsize=15, rotation=0)
ax.set_title('Inferred Bedmap viscosity $\\mu(x,y)$ (log scale)', fontsize=15)

fig.savefig(f"{output_dir}/inferred_visc_logscale_fixed.png", dpi=300, bbox_inches='tight')
plt.show()
